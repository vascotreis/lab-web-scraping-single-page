# %% [markdown]
# # LAB Monday: Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.billboard.com/charts/hot-100/'

# %%
results=requests.get(url, headers ={'Accept-Language':'en-US'})

# %%
soup = BeautifulSoup(results.content,'html.parser')

# %%
soup.select('h3.c-title.a-no-trucate')[0].get_text(strip=True)
# Out:
# 'Anti-Hero'

# %%
soup.select('span.c-label.a-no-trucate')[0].get_text(strip=True)
# Out:
# 'Taylor Swift'

# %%
title=[]
artists=[]

len_songs=len(soup.select('h3.c-title.a-no-trucate'))

# %%
len_songs
# Out:
# 100

# %%
for i in range(len_songs):
    title.append(soup.select('h3.c-title.a-no-trucate')[i].get_text(strip=True))
    artists.append(soup.select('span.c-label.a-no-trucate')[i].get_text(strip=True))

# %%
# title_df=[]
# artist_df=[]

# for songs in title:
#     title_df.append(songs.replace('\n', ''))

# for songs in artists:
#     artist_df.append(songs.replace('\n', ''))


# using strip=True in the step before it is not necessary to replace \n

# %%
len(title)
# Out:
# 100

# %%
len(artists)
# Out:
# 100

# %%
import pandas as pd

songs=pd.DataFrame({'Song_title':title, 'Artists':artists})
songs
# Out:
#                  Song_title                    Artists
# 0                 Anti-Hero               Taylor Swift
# 1                    Unholy     Sam Smith & Kim Petras
# 2                 Kill Bill                        SZA
# 3           I'm Good (Blue)  David Guetta & Bebe Rexha
# 4                 Rich Flex          Drake & 21 Savage
# ..                      ...                        ...
# 95  Shut Up My Moms Calling                 Hotel Ugly
# 96            Midnight Rain               Taylor Swift
# 97                  Players                  Coi Leray
# 98       Major Distribution          Drake & 21 Savage
# 99                Notice Me                        SZA
#
# [100 rows x 2 columns]

# %%
import numpy as np
songs['Rank']=np.arange(len(songs))+1

# %%
songs
# Out:
#                  Song_title                    Artists  Rank
# 0                 Anti-Hero               Taylor Swift     1
# 1                    Unholy     Sam Smith & Kim Petras     2
# 2                 Kill Bill                        SZA     3
# 3           I'm Good (Blue)  David Guetta & Bebe Rexha     4
# 4                 Rich Flex          Drake & 21 Savage     5
# ..                      ...                        ...   ...
# 95  Shut Up My Moms Calling                 Hotel Ugly    96
# 96            Midnight Rain               Taylor Swift    97
# 97                  Players                  Coi Leray    98
# 98       Major Distribution          Drake & 21 Savage    99
# 99                Notice Me                        SZA   100
#
# [100 rows x 3 columns]

# %%
# LAB Tuesday: Prototype with user input

# %% [markdown]
# # LAB Wednesday: API wrappers - Create your collection of songs & audio features

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist=sp.user_playlist_tracks('PMB Music','69tUdeFaKRDVTg2guSDttx')

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['items'][4]['track']['id']
# Out:
# '7oWqXVRExRlNR0jZJNoO9w'

# %%
playlist['total']
# Out:
# 1038

# %%
len(playlist['items'])
# Out:
# 100

# %%
# user_id='Bradnumber1'
# playlist_id='1YL4XoegERoragv0RK2RC9'

# %%
user_id='PMB Music'
playlist_id='69tUdeFaKRDVTg2guSDttx'

# %%
def get_playlist_tracks(user_id,playlist_id):
    results = sp.user_playlist_tracks(user_id,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
full_track_ids=get_playlist_tracks(user_id,playlist_id)

# %%
len(full_track_ids)
# Out:
# 1038

# %%
full_track_ids[0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
full_track_ids[0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
full_track_ids[0]['track']['name']
# Out:
# 'Original Sin'

# %%
full_track_ids[0]['track']['artists'][0]['name']
# Out:
# 'INXS'

# %%
full_track_ids[0]['track']['id']
# Out:
# '7pSzRRMaPXA39wvrnvdmSH'

# %%
title=[]
artist=[]
song_id=[]

for i in full_track_ids:
    title.append(i['track']['name'])
    artist.append(i['track']['artists'][0]['name'])
    song_id.append(i['track']['id'])

# %%
playlist_df=pd.DataFrame({'title': title, 'artist': artist, 'song_id': song_id})

# %%
playlist_df
# Out:
#                                      title               artist  \
# 0                             Original Sin                 INXS
# 1                                 Sussudio         Phil Collins
# 2              Don't You (Forget About Me)         Simple Minds
# 3                               Everywhere        Fleetwood Mac
# 4                               High & Dry                  ABC
# ...                                    ...                  ...
# 1033  If I Should Fall From Grace With God           The Pogues
# 1034                The Devil's Right Hand          Steve Earle
# 1035                 Europe After the Rain            John Foxx
# 1036            That's What You Always Say  The Dream Syndicate
# 1037   I'm In Love With A German Film Star         The Passions
#
#                      song_id
# 0     7pSzRRMaPXA39wvrnvdmSH
# 1     07zkNvtcmPOFlMOXbma13k
# 2     603aPXFY2Ec2WuFganUGuD
# 3     6i8ecOsx4J2Px1maiqzqoG
# 4     7oWqXVRExRlNR0jZJNoO9w
# ...                      ...
# 1033  2QlYQQ8JpZf8mAk7PWcXsB
# 1034  59JOneFVktVPSm0agaQWDo
# 1035  7p1wyDdcnJuwQDodZh1Duq
# 1036  7jgfLVXTBxufrbccakHQi1
# 1037  2pzc7K0AdUySB4V0SFMENJ
#
# [1038 rows x 3 columns]

# %%
spaceplaylist=[]
for i in range(len(playlist_df)):
    spaceplaylist.extend(sp.audio_features(tracks=playlist_df['song_id'][i]))

# %%
song_features=pd.DataFrame.from_dict(spaceplaylist)

# %%
song_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.685   0.633    9    -7.259     1       0.0377       0.01360
# 1            0.736   0.838    0    -6.932     1       0.0725       0.01540
# 2            0.663   0.629    2   -12.697     1       0.0260       0.08360
# 3            0.690   0.540    4   -10.516     1       0.0317       0.21800
# 4            0.571   0.747    4    -7.989     1       0.0267       0.06700
# ...            ...     ...  ...       ...   ...          ...           ...
# 1033         0.454   0.952    9    -8.938     1       0.0536       0.01500
# 1034         0.560   0.702   11    -9.810     1       0.0419       0.06250
# 1035         0.523   0.788    4    -9.512     1       0.0332       0.00774
# 1036         0.614   0.918    9    -7.129     0       0.0600       0.05220
# 1037         0.763   0.530   11   -12.306     1       0.0381       0.27800
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000106    0.0935    0.731  131.397  audio_features
# 1             0.060800    0.0454    0.790  121.242  audio_features
# 2             0.039400    0.1050    0.648  111.290  audio_features
# 3             0.006570    0.1150    0.764  114.846  audio_features
# 4             0.000018    0.1010    0.602   95.997  audio_features
# ...                ...       ...      ...      ...             ...
# 1033          0.017800    0.1420    0.589  129.678  audio_features
# 1034          0.000000    0.0951    0.848  126.866  audio_features
# 1035          0.000014    0.2650    0.648  142.393  audio_features
# 1036          0.085000    0.0840    0.734  125.755  audio_features
# 1037          0.019000    0.1090    0.414  114.601  audio_features
#
#                           id                                   uri  \
# 0     7pSzRRMaPXA39wvrnvdmSH  spotify:track:7pSzRRMaPXA39wvrnvdmSH
# 1     07zkNvtcmPOFlMOXbma13k  spotify:track:07zkNvtcmPOFlMOXbma13k
# 2     603aPXFY2Ec2WuFganUGuD  spotify:track:603aPXFY2Ec2WuFganUGuD
# 3     6i8ecOsx4J2Px1maiqzqoG  spotify:track:6i8ecOsx4J2Px1maiqzqoG
# 4     7oWqXVRExRlNR0jZJNoO9w  spotify:track:7oWqXVRExRlNR0jZJNoO9w
# ...                      ...                                   ...
# 1033  2QlYQQ8JpZf8mAk7PWcXsB  spotify:track:2QlYQQ8JpZf8mAk7PWcXsB
# 1034  59JOneFVktVPSm0agaQWDo  spotify:track:59JOneFVktVPSm0agaQWDo
# 1035  7p1wyDdcnJuwQDodZh1Duq  spotify:track:7p1wyDdcnJuwQDodZh1Duq
# 1036  7jgfLVXTBxufrbccakHQi1  spotify:track:7jgfLVXTBxufrbccakHQi1
# 1037  2pzc7K0AdUySB4V0SFMENJ  spotify:track:2pzc7K0AdUySB4V0SFMENJ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7pSzRRMaPXA3...
# 1     https://api.spotify.com/v1/tracks/07zkNvtcmPOF...
# 2     https://api.spotify.com/v1/tracks/603aPXFY2Ec2...
# 3     https://api.spotify.com/v1/tracks/6i8ecOsx4J2P...
# 4     https://api.spotify.com/v1/tracks/7oWqXVRExRlN...
# ...                                                 ...
# 1033  https://api.spotify.com/v1/tracks/2QlYQQ8JpZf8...
# 1034  https://api.spotify.com/v1/tracks/59JOneFVktVP...
# 1035  https://api.spotify.com/v1/tracks/7p1wyDdcnJuw...
# 1036  https://api.spotify.com/v1/tracks/7jgfLVXTBxuf...
# 1037  https://api.spotify.com/v1/tracks/2pzc7K0AdUyS...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7pSz...       317240
# 1     https://api.spotify.com/v1/audio-analysis/07zk...       264947
# 2     https://api.spotify.com/v1/audio-analysis/603a...       260867
# 3     https://api.spotify.com/v1/audio-analysis/6i8e...       222733
# 4     https://api.spotify.com/v1/audio-analysis/7oWq...       264587
# ...                                                 ...          ...
# 1033  https://api.spotify.com/v1/audio-analysis/2QlY...       140693
# 1034  https://api.spotify.com/v1/audio-analysis/59JO...       181400
# 1035  https://api.spotify.com/v1/audio-analysis/7p1w...       240573
# 1036  https://api.spotify.com/v1/audio-analysis/7jgf...       192973
# 1037  https://api.spotify.com/v1/audio-analysis/2pzc...       239560
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1033               4
# 1034               4
# 1035               4
# 1036               4
# 1037               4
#
# [1038 rows x 18 columns]

# %%
playlist_features = playlist_df.merge(song_features, left_on='song_id', right_on='id')

# %%
playlist_features
# Out:
#                                      title               artist  \
# 0                             Original Sin                 INXS
# 1                                 Sussudio         Phil Collins
# 2              Don't You (Forget About Me)         Simple Minds
# 3                               Everywhere        Fleetwood Mac
# 4                               High & Dry                  ABC
# ...                                    ...                  ...
# 1033  If I Should Fall From Grace With God           The Pogues
# 1034                The Devil's Right Hand          Steve Earle
# 1035                 Europe After the Rain            John Foxx
# 1036            That's What You Always Say  The Dream Syndicate
# 1037   I'm In Love With A German Film Star         The Passions
#
#                      song_id  danceability  energy  key  loudness  mode  \
# 0     7pSzRRMaPXA39wvrnvdmSH         0.685   0.633    9    -7.259     1
# 1     07zkNvtcmPOFlMOXbma13k         0.736   0.838    0    -6.932     1
# 2     603aPXFY2Ec2WuFganUGuD         0.663   0.629    2   -12.697     1
# 3     6i8ecOsx4J2Px1maiqzqoG         0.690   0.540    4   -10.516     1
# 4     7oWqXVRExRlNR0jZJNoO9w         0.571   0.747    4    -7.989     1
# ...                      ...           ...     ...  ...       ...   ...
# 1033  2QlYQQ8JpZf8mAk7PWcXsB         0.454   0.952    9    -8.938     1
# 1034  59JOneFVktVPSm0agaQWDo         0.560   0.702   11    -9.810     1
# 1035  7p1wyDdcnJuwQDodZh1Duq         0.523   0.788    4    -9.512     1
# 1036  7jgfLVXTBxufrbccakHQi1         0.614   0.918    9    -7.129     0
# 1037  2pzc7K0AdUySB4V0SFMENJ         0.763   0.530   11   -12.306     1
#
#       speechiness  acousticness  ...  liveness  valence    tempo  \
# 0          0.0377       0.01360  ...    0.0935    0.731  131.397
# 1          0.0725       0.01540  ...    0.0454    0.790  121.242
# 2          0.0260       0.08360  ...    0.1050    0.648  111.290
# 3          0.0317       0.21800  ...    0.1150    0.764  114.846
# 4          0.0267       0.06700  ...    0.1010    0.602   95.997
# ...           ...           ...  ...       ...      ...      ...
# 1033       0.0536       0.01500  ...    0.1420    0.589  129.678
# 1034       0.0419       0.06250  ...    0.0951    0.848  126.866
# 1035       0.0332       0.00774  ...    0.2650    0.648  142.393
# 1036       0.0600       0.05220  ...    0.0840    0.734  125.755
# 1037       0.0381       0.27800  ...    0.1090    0.414  114.601
#
#                 type                      id  \
# 0     audio_features  7pSzRRMaPXA39wvrnvdmSH
# 1     audio_features  07zkNvtcmPOFlMOXbma13k
# 2     audio_features  603aPXFY2Ec2WuFganUGuD
# 3     audio_features  6i8ecOsx4J2Px1maiqzqoG
# 4     audio_features  7oWqXVRExRlNR0jZJNoO9w
# ...              ...                     ...
# 1033  audio_features  2QlYQQ8JpZf8mAk7PWcXsB
# 1034  audio_features  59JOneFVktVPSm0agaQWDo
# 1035  audio_features  7p1wyDdcnJuwQDodZh1Duq
# 1036  audio_features  7jgfLVXTBxufrbccakHQi1
# 1037  audio_features  2pzc7K0AdUySB4V0SFMENJ
#
#                                        uri  \
# 0     spotify:track:7pSzRRMaPXA39wvrnvdmSH
# 1     spotify:track:07zkNvtcmPOFlMOXbma13k
# 2     spotify:track:603aPXFY2Ec2WuFganUGuD
# 3     spotify:track:6i8ecOsx4J2Px1maiqzqoG
# 4     spotify:track:7oWqXVRExRlNR0jZJNoO9w
# ...                                    ...
# 1033  spotify:track:2QlYQQ8JpZf8mAk7PWcXsB
# 1034  spotify:track:59JOneFVktVPSm0agaQWDo
# 1035  spotify:track:7p1wyDdcnJuwQDodZh1Duq
# 1036  spotify:track:7jgfLVXTBxufrbccakHQi1
# 1037  spotify:track:2pzc7K0AdUySB4V0SFMENJ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7pSzRRMaPXA3...
# 1     https://api.spotify.com/v1/tracks/07zkNvtcmPOF...
# 2     https://api.spotify.com/v1/tracks/603aPXFY2Ec2...
# 3     https://api.spotify.com/v1/tracks/6i8ecOsx4J2P...
# 4     https://api.spotify.com/v1/tracks/7oWqXVRExRlN...
# ...                                                 ...
# 1033  https://api.spotify.com/v1/tracks/2QlYQQ8JpZf8...
# 1034  https://api.spotify.com/v1/tracks/59JOneFVktVP...
# 1035  https://api.spotify.com/v1/tracks/7p1wyDdcnJuw...
# 1036  https://api.spotify.com/v1/tracks/7jgfLVXTBxuf...
# 1037  https://api.spotify.com/v1/tracks/2pzc7K0AdUyS...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7pSz...      317240
# 1     https://api.spotify.com/v1/audio-analysis/07zk...      264947
# 2     https://api.spotify.com/v1/audio-analysis/603a...      260867
# 3     https://api.spotify.com/v1/audio-analysis/6i8e...      222733
# 4     https://api.spotify.com/v1/audio-analysis/7oWq...      264587
# ...                                                 ...         ...
# 1033  https://api.spotify.com/v1/audio-analysis/2QlY...      140693
# 1034  https://api.spotify.com/v1/audio-analysis/59JO...      181400
# 1035  https://api.spotify.com/v1/audio-analysis/7p1w...      240573
# 1036  https://api.spotify.com/v1/audio-analysis/7jgf...      192973
# 1037  https://api.spotify.com/v1/audio-analysis/2pzc...      239560
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1033               4
# 1034               4
# 1035               4
# 1036               4
# 1037               4
#
# [1038 rows x 21 columns]

# %%
playlist_features=playlist_features.drop(['id'],axis=1)

# %%
# ingredients
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings("ignore")

# %%
playlist_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 0 to 1037
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             1038 non-null   object
#  1   artist            1038 non-null   object
#  2   song_id           1038 non-null   object
#  3   danceability      1038 non-null   float64
#  4   energy            1038 non-null   float64
#  5   key               1038 non-null   int64
#  6   loudness          1038 non-null   float64
#  7   mode              1038 non-null   int64
#  8   speechiness       1038 non-null   float64
#  9   acousticness      1038 non-null   float64
#  10  instrumentalness  1038 non-null   float64
#  11  liveness          1038 non-null   float64
#  12  valence           1038 non-null   float64
#  13  tempo             1038 non-null   float64
#  14  type              1038 non-null   object
#  15  uri               1038 non-null   object
#  16  track_href        1038 non-null   object
#  17  analysis_url      1038 non-null   object
#  18  duration_ms       1038 non-null   int64
#  19  time_signature    1038 non-null   int64
# dtypes: float64(9), int64(4), object(7)
# memory usage: 170.3+ KB

# %%
playlist_features.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   1038.000000  1038.000000  1038.000000  1038.000000  1038.000000
# mean       0.632296     0.687339     5.324663    -9.279781     0.699422
# std        0.133206     0.182735     3.614445     3.338145     0.458730
# min        0.147000     0.160000     0.000000   -22.597000     0.000000
# 25%        0.546250     0.557250     2.000000   -11.725750     0.000000
# 50%        0.639000     0.711000     5.000000    -8.857000     1.000000
# 75%        0.726750     0.833750     9.000000    -6.687750     1.000000
# max        0.968000     0.991000    11.000000    -2.658000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  1038.000000   1038.000000       1038.000000  1038.000000  1038.000000
# mean      0.046271      0.172357          0.051059     0.172441     0.667612
# std       0.038632      0.190307          0.152257     0.148771     0.227751
# min       0.021500      0.000005          0.000000     0.016500     0.050500
# 25%       0.031100      0.026850          0.000004     0.075875     0.510250
# 50%       0.037500      0.102500          0.000212     0.114500     0.709500
# 75%       0.048900      0.254500          0.008310     0.242000     0.857000
# max       0.934000      0.941000          0.927000     0.988000     0.985000
#
#              tempo    duration_ms  time_signature
# count  1038.000000    1038.000000     1038.000000
# mean    122.128461  256884.836224        3.993256
# std      23.690125   58412.013047        0.102772
# min      56.832000  122760.000000        3.000000
# 25%     108.016500  221096.500000        4.000000
# 50%     120.251000  245553.000000        4.000000
# 75%     132.717000  281169.750000        4.000000
# max     205.218000  730800.000000        5.000000

# %%
cluster_df=playlist_features.drop(['title','artist','type','uri','track_href','analysis_url'],axis=1)

# %%
cluster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 0 to 1037
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_id           1038 non-null   object
#  1   danceability      1038 non-null   float64
#  2   energy            1038 non-null   float64
#  3   key               1038 non-null   int64
#  4   loudness          1038 non-null   float64
#  5   mode              1038 non-null   int64
#  6   speechiness       1038 non-null   float64
#  7   acousticness      1038 non-null   float64
#  8   instrumentalness  1038 non-null   float64
#  9   liveness          1038 non-null   float64
#  10  valence           1038 non-null   float64
#  11  tempo             1038 non-null   float64
#  12  duration_ms       1038 non-null   int64
#  13  time_signature    1038 non-null   int64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 121.6+ KB

# %%
cluster_df.index=cluster_df.iloc[:,0]

# %%
cluster_df
# Out:
#                                        song_id  danceability  energy  key  \
# song_id
# 7pSzRRMaPXA39wvrnvdmSH  7pSzRRMaPXA39wvrnvdmSH         0.685   0.633    9
# 07zkNvtcmPOFlMOXbma13k  07zkNvtcmPOFlMOXbma13k         0.736   0.838    0
# 603aPXFY2Ec2WuFganUGuD  603aPXFY2Ec2WuFganUGuD         0.663   0.629    2
# 6i8ecOsx4J2Px1maiqzqoG  6i8ecOsx4J2Px1maiqzqoG         0.690   0.540    4
# 7oWqXVRExRlNR0jZJNoO9w  7oWqXVRExRlNR0jZJNoO9w         0.571   0.747    4
# ...                                        ...           ...     ...  ...
# 2QlYQQ8JpZf8mAk7PWcXsB  2QlYQQ8JpZf8mAk7PWcXsB         0.454   0.952    9
# 59JOneFVktVPSm0agaQWDo  59JOneFVktVPSm0agaQWDo         0.560   0.702   11
# 7p1wyDdcnJuwQDodZh1Duq  7p1wyDdcnJuwQDodZh1Duq         0.523   0.788    4
# 7jgfLVXTBxufrbccakHQi1  7jgfLVXTBxufrbccakHQi1         0.614   0.918    9
# 2pzc7K0AdUySB4V0SFMENJ  2pzc7K0AdUySB4V0SFMENJ         0.763   0.530   11
#
#                         loudness  mode  speechiness  acousticness  \
# song_id
# 7pSzRRMaPXA39wvrnvdmSH    -7.259     1       0.0377       0.01360
# 07zkNvtcmPOFlMOXbma13k    -6.932     1       0.0725       0.01540
# 603aPXFY2Ec2WuFganUGuD   -12.697     1       0.0260       0.08360
# 6i8ecOsx4J2Px1maiqzqoG   -10.516     1       0.0317       0.21800
# 7oWqXVRExRlNR0jZJNoO9w    -7.989     1       0.0267       0.06700
# ...                          ...   ...          ...           ...
# 2QlYQQ8JpZf8mAk7PWcXsB    -8.938     1       0.0536       0.01500
# 59JOneFVktVPSm0agaQWDo    -9.810     1       0.0419       0.06250
# 7p1wyDdcnJuwQDodZh1Duq    -9.512     1       0.0332       0.00774
# 7jgfLVXTBxufrbccakHQi1    -7.129     0       0.0600       0.05220
# 2pzc7K0AdUySB4V0SFMENJ   -12.306     1       0.0381       0.27800
#
#                         instrumentalness  liveness  valence    tempo  \
# song_id
# 7pSzRRMaPXA39wvrnvdmSH          0.000106    0.0935    0.731  131.397
# 07zkNvtcmPOFlMOXbma13k          0.060800    0.0454    0.790  121.242
# 603aPXFY2Ec2WuFganUGuD          0.039400    0.1050    0.648  111.290
# 6i8ecOsx4J2Px1maiqzqoG          0.006570    0.1150    0.764  114.846
# 7oWqXVRExRlNR0jZJNoO9w          0.000018    0.1010    0.602   95.997
# ...                                  ...       ...      ...      ...
# 2QlYQQ8JpZf8mAk7PWcXsB          0.017800    0.1420    0.589  129.678
# 59JOneFVktVPSm0agaQWDo          0.000000    0.0951    0.848  126.866
# 7p1wyDdcnJuwQDodZh1Duq          0.000014    0.2650    0.648  142.393
# 7jgfLVXTBxufrbccakHQi1          0.085000    0.0840    0.734  125.755
# 2pzc7K0AdUySB4V0SFMENJ          0.019000    0.1090    0.414  114.601
#
#                         duration_ms  time_signature
# song_id
# 7pSzRRMaPXA39wvrnvdmSH       317240               4
# 07zkNvtcmPOFlMOXbma13k       264947               4
# 603aPXFY2Ec2WuFganUGuD       260867               4
# 6i8ecOsx4J2Px1maiqzqoG       222733               4
# 7oWqXVRExRlNR0jZJNoO9w       264587               4
# ...                             ...             ...
# 2QlYQQ8JpZf8mAk7PWcXsB       140693               4
# 59JOneFVktVPSm0agaQWDo       181400               4
# 7p1wyDdcnJuwQDodZh1Duq       240573               4
# 7jgfLVXTBxufrbccakHQi1       192973               4
# 2pzc7K0AdUySB4V0SFMENJ       239560               4
#
# [1038 rows x 14 columns]

# %%
cluster_df=cluster_df.iloc[:,1:14]
cluster_df
# Out:
#                         danceability  energy  key  loudness  mode  \
# song_id
# 7pSzRRMaPXA39wvrnvdmSH         0.685   0.633    9    -7.259     1
# 07zkNvtcmPOFlMOXbma13k         0.736   0.838    0    -6.932     1
# 603aPXFY2Ec2WuFganUGuD         0.663   0.629    2   -12.697     1
# 6i8ecOsx4J2Px1maiqzqoG         0.690   0.540    4   -10.516     1
# 7oWqXVRExRlNR0jZJNoO9w         0.571   0.747    4    -7.989     1
# ...                              ...     ...  ...       ...   ...
# 2QlYQQ8JpZf8mAk7PWcXsB         0.454   0.952    9    -8.938     1
# 59JOneFVktVPSm0agaQWDo         0.560   0.702   11    -9.810     1
# 7p1wyDdcnJuwQDodZh1Duq         0.523   0.788    4    -9.512     1
# 7jgfLVXTBxufrbccakHQi1         0.614   0.918    9    -7.129     0
# 2pzc7K0AdUySB4V0SFMENJ         0.763   0.530   11   -12.306     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# song_id
# 7pSzRRMaPXA39wvrnvdmSH       0.0377       0.01360          0.000106    0.0935
# 07zkNvtcmPOFlMOXbma13k       0.0725       0.01540          0.060800    0.0454
# 603aPXFY2Ec2WuFganUGuD       0.0260       0.08360          0.039400    0.1050
# 6i8ecOsx4J2Px1maiqzqoG       0.0317       0.21800          0.006570    0.1150
# 7oWqXVRExRlNR0jZJNoO9w       0.0267       0.06700          0.000018    0.1010
# ...                             ...           ...               ...       ...
# 2QlYQQ8JpZf8mAk7PWcXsB       0.0536       0.01500          0.017800    0.1420
# 59JOneFVktVPSm0agaQWDo       0.0419       0.06250          0.000000    0.0951
# 7p1wyDdcnJuwQDodZh1Duq       0.0332       0.00774          0.000014    0.2650
# 7jgfLVXTBxufrbccakHQi1       0.0600       0.05220          0.085000    0.0840
# 2pzc7K0AdUySB4V0SFMENJ       0.0381       0.27800          0.019000    0.1090
#
#                         valence    tempo  duration_ms  time_signature
# song_id
# 7pSzRRMaPXA39wvrnvdmSH    0.731  131.397       317240               4
# 07zkNvtcmPOFlMOXbma13k    0.790  121.242       264947               4
# 603aPXFY2Ec2WuFganUGuD    0.648  111.290       260867               4
# 6i8ecOsx4J2Px1maiqzqoG    0.764  114.846       222733               4
# 7oWqXVRExRlNR0jZJNoO9w    0.602   95.997       264587               4
# ...                         ...      ...          ...             ...
# 2QlYQQ8JpZf8mAk7PWcXsB    0.589  129.678       140693               4
# 59JOneFVktVPSm0agaQWDo    0.848  126.866       181400               4
# 7p1wyDdcnJuwQDodZh1Duq    0.648  142.393       240573               4
# 7jgfLVXTBxufrbccakHQi1    0.734  125.755       192973               4
# 2pzc7K0AdUySB4V0SFMENJ    0.414  114.601       239560               4
#
# [1038 rows x 13 columns]

# %%
cluster_df.rename_axis(None, inplace=True)
cluster_df
# Out:
#                         danceability  energy  key  loudness  mode  \
# 7pSzRRMaPXA39wvrnvdmSH         0.685   0.633    9    -7.259     1
# 07zkNvtcmPOFlMOXbma13k         0.736   0.838    0    -6.932     1
# 603aPXFY2Ec2WuFganUGuD         0.663   0.629    2   -12.697     1
# 6i8ecOsx4J2Px1maiqzqoG         0.690   0.540    4   -10.516     1
# 7oWqXVRExRlNR0jZJNoO9w         0.571   0.747    4    -7.989     1
# ...                              ...     ...  ...       ...   ...
# 2QlYQQ8JpZf8mAk7PWcXsB         0.454   0.952    9    -8.938     1
# 59JOneFVktVPSm0agaQWDo         0.560   0.702   11    -9.810     1
# 7p1wyDdcnJuwQDodZh1Duq         0.523   0.788    4    -9.512     1
# 7jgfLVXTBxufrbccakHQi1         0.614   0.918    9    -7.129     0
# 2pzc7K0AdUySB4V0SFMENJ         0.763   0.530   11   -12.306     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 7pSzRRMaPXA39wvrnvdmSH       0.0377       0.01360          0.000106    0.0935
# 07zkNvtcmPOFlMOXbma13k       0.0725       0.01540          0.060800    0.0454
# 603aPXFY2Ec2WuFganUGuD       0.0260       0.08360          0.039400    0.1050
# 6i8ecOsx4J2Px1maiqzqoG       0.0317       0.21800          0.006570    0.1150
# 7oWqXVRExRlNR0jZJNoO9w       0.0267       0.06700          0.000018    0.1010
# ...                             ...           ...               ...       ...
# 2QlYQQ8JpZf8mAk7PWcXsB       0.0536       0.01500          0.017800    0.1420
# 59JOneFVktVPSm0agaQWDo       0.0419       0.06250          0.000000    0.0951
# 7p1wyDdcnJuwQDodZh1Duq       0.0332       0.00774          0.000014    0.2650
# 7jgfLVXTBxufrbccakHQi1       0.0600       0.05220          0.085000    0.0840
# 2pzc7K0AdUySB4V0SFMENJ       0.0381       0.27800          0.019000    0.1090
#
#                         valence    tempo  duration_ms  time_signature
# 7pSzRRMaPXA39wvrnvdmSH    0.731  131.397       317240               4
# 07zkNvtcmPOFlMOXbma13k    0.790  121.242       264947               4
# 603aPXFY2Ec2WuFganUGuD    0.648  111.290       260867               4
# 6i8ecOsx4J2Px1maiqzqoG    0.764  114.846       222733               4
# 7oWqXVRExRlNR0jZJNoO9w    0.602   95.997       264587               4
# ...                         ...      ...          ...             ...
# 2QlYQQ8JpZf8mAk7PWcXsB    0.589  129.678       140693               4
# 59JOneFVktVPSm0agaQWDo    0.848  126.866       181400               4
# 7p1wyDdcnJuwQDodZh1Duq    0.648  142.393       240573               4
# 7jgfLVXTBxufrbccakHQi1    0.734  125.755       192973               4
# 2pzc7K0AdUySB4V0SFMENJ    0.414  114.601       239560               4
#
# [1038 rows x 13 columns]

# %%
K_Means=KMeans(n_clusters=5, random_state=5)
cluster_model_nonscaled=K_Means.fit(cluster_df)
cluster_model_nonscaled.cluster_centers_
# Out:
# array([[ 6.28376923e-01,  6.77034615e-01,  5.43846154e+00,
#         -9.43533462e+00,  6.57692308e-01,  4.32034615e-02,
#          1.68546485e-01,  3.38214625e-02,  1.79388846e-01,
#          6.50317308e-01,  1.23136550e+02,  2.82013142e+05,
#          3.99230769e+00],
#        [ 5.95327273e-01,  6.54736364e-01,  5.24545455e+00,
#         -9.68935455e+00,  6.63636364e-01,  4.91936364e-02,
#          1.85671764e-01,  6.26100946e-02,  1.59852727e-01,
#          5.85946364e-01,  1.17494718e+02,  3.46200755e+05,
#          3.99090909e+00],
#        [ 6.39630588e-01,  6.82397647e-01,  5.39058824e+00,
#         -9.21416941e+00,  7.15294118e-01,  4.27242353e-02,
#          1.71785895e-01,  4.83575610e-02,  1.69781647e-01,
#          6.71717882e-01,  1.20841155e+02,  2.37969781e+05,
#          3.99764706e+00],
#        [ 7.01227273e-01,  6.27681818e-01,  5.36363636e+00,
#         -1.06832727e+01,  5.90909091e-01,  5.23500000e-02,
#          1.11954164e-01,  1.17604626e-01,  1.51413636e-01,
#          6.43272727e-01,  1.13752500e+02,  4.84429909e+05,
#          4.00000000e+00],
#        [ 6.34339367e-01,  7.31131222e-01,  5.09954751e+00,
#         -8.87938009e+00,  7.46606335e-01,  5.46398190e-02,
#          1.77321653e-01,  6.41606576e-02,  1.77741176e-01,
#          7.23135747e-01,  1.26558258e+02,  1.96589796e+05,
#          3.98642534e+00]])

# %%
cluster_model_nonscaled.labels_
# Out:
# array([1, 0, 0, ..., 2, 4, 2], dtype=int32)

# %%
cluster_df['cluster_no_sc']=cluster_model_nonscaled.labels_

# %%
cluster_df['cluster_no_sc'].value_counts()
# Out:
# 2    424
# 0    260
# 4    222
# 1    110
# 3     22
# Name: cluster_no_sc, dtype: int64

# %%
cluster_df.head(1)
# Out:
#                         danceability  energy  key  loudness  mode  \
# 7pSzRRMaPXA39wvrnvdmSH         0.685   0.633    9    -7.259     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 7pSzRRMaPXA39wvrnvdmSH       0.0377        0.0136          0.000106    0.0935
#
#                         valence    tempo  duration_ms  time_signature  \
# 7pSzRRMaPXA39wvrnvdmSH    0.731  131.397       317240               4
#
#                         cluster_no_sc
# 7pSzRRMaPXA39wvrnvdmSH              1

# %%
plt.scatter(cluster_df.iloc[:,0], cluster_df.iloc[:,1], cluster_df.iloc[:,2], cluster_df.iloc[:,4]);

# %%
cluster_df=cluster_df.drop('cluster_no_sc',axis=1)

# %%
#Scaling
cluster_df_copy=cluster_df
cluster_scaled=K_Means.fit(cluster_df_copy)
cluster_df_copy['cluster_sc']=cluster_scaled.labels_

# %%
scaler=StandardScaler()
scaler.fit(cluster_df_copy)
scaler.mean_
# Out:
# array([ 6.32295761e-01,  6.87339114e-01,  5.32466281e+00, -9.27978131e+00,
#         6.99421965e-01,  4.62708092e-02,  1.72356515e-01,  5.10592112e-02,
#         1.72441233e-01,  6.67612428e-01,  1.22128461e+02,  2.56884836e+05,
#         3.99325626e+00,  1.84200385e+00])

# %%
cluster_scaled=scaler.transform(cluster_df_copy)

# %%
cluster_scaled.shape
# Out:
# (1038, 14)

# %%
type(cluster_scaled)
cluster_scaled_df=pd.DataFrame(cluster_scaled,columns=['danceability' , 'energy' , 'key' , 'loudness' , 'mode' , 'speechiness' , 'acousticness' , 'instrumentalness' , 'liveness' , 'valence' , 'tempo' , 'duration_ms' , 'time_signature', 'cluster_sc'])
cluster_scaled_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         0.395849 -0.297509  1.017337  0.605652  0.655555    -0.221964
# 1         0.778898  0.824874 -1.473872  0.703658  0.655555     0.679276
# 2         0.230612 -0.319409 -0.920270 -1.024181  0.655555    -0.524967
# 3         0.433403 -0.806687 -0.366668 -0.370510  0.655555    -0.377350
# 4        -0.460378  0.326646 -0.366668  0.386863  0.655555    -0.506839
# ...            ...       ...       ...       ...       ...          ...
# 1033     -1.339137  1.449028  1.017337  0.102436  0.655555     0.189809
# 1034     -0.542996  0.080269  1.570939 -0.158913  0.655555    -0.113194
# 1035     -0.820895  0.551122 -0.366668 -0.069599  0.655555    -0.338504
# 1036     -0.137415  1.262877  1.017337  0.644615 -1.525426     0.355554
# 1037      0.981689 -0.861437  1.570939 -0.906994  0.655555    -0.211605
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0        -0.834617         -0.334815 -0.530878  0.278454  0.391429
# 1        -0.825154          0.064007 -0.854350  0.537633 -0.037437
# 2        -0.466612         -0.076613 -0.453541 -0.086155 -0.457730
# 3         0.239958         -0.292340 -0.386291  0.423419 -0.307553
# 4        -0.553882         -0.335394 -0.480441 -0.288227 -1.103585
# ...            ...               ...       ...       ...       ...
# 1033     -0.827257         -0.218547 -0.204717 -0.345335  0.318832
# 1034     -0.577539         -0.335511 -0.520118  0.792420  0.200076
# 1035     -0.865424         -0.335422  0.622456 -0.086155  0.855813
# 1036     -0.631688          0.223026 -0.594766  0.291632  0.153156
# 1037      0.555390         -0.210662 -0.426641 -1.114088 -0.317900
#
#       duration_ms  time_signature  cluster_sc
# 0        1.033764         0.06565   -0.601489
# 1        0.138089         0.06565   -1.315844
# 2        0.068207         0.06565   -1.315844
# 3       -0.584953         0.06565    0.112865
# 4        0.131923         0.06565   -1.315844
# ...           ...             ...         ...
# 1033    -1.990136         0.06565    1.541574
# 1034    -1.292906         0.06565    1.541574
# 1035    -0.279389         0.06565    0.112865
# 1036    -1.094683         0.06565    1.541574
# 1037    -0.296740         0.06565    0.112865
#
# [1038 rows x 14 columns]

# %%
#we compare with the original no scaled checking if more or less has the same pattern
cluster_df.hist(bins=15,figsize=(15,15));

# %%
cluster_scaled_df.hist(bins=15,figsize=(15,15));

# %%
K_Means=KMeans(n_clusters=5, random_state=5)
cluster_model_scaled=K_Means.fit(cluster_scaled_df)
cluster_model_scaled.cluster_centers_
# Out:
# array([[ 2.89581896e-01,  5.46940543e-02,  4.17601529e-01,
#         -6.95351942e-03, -1.52542554e+00, -1.32050904e-03,
#         -2.82265645e-01, -1.82058901e-01, -8.78292694e-02,
#          1.66362167e-01, -9.98459236e-02,  3.32947877e-01,
#          6.56503290e-02, -4.24509480e-01],
#        [ 1.31020391e-01,  1.92491667e-01, -2.68145615e-01,
#          1.40799936e-01,  6.49393816e-01, -4.31677002e-02,
#         -2.82378490e-01, -1.87842308e-01,  1.00597417e-01,
#          2.21780647e-01, -1.39654087e-01,  2.99184437e-01,
#          9.31503457e-02, -4.96555762e-01],
#        [-5.46402362e-01, -1.40028282e+00,  5.97986686e-02,
#         -8.45540860e-01,  2.49790997e-01, -2.85082387e-01,
#          1.25901558e+00, -2.13909856e-01, -2.43217217e-01,
#         -1.25066534e+00, -3.85164302e-01,  1.80772710e-01,
#         -3.30541773e-01, -1.73707169e-01],
#        [ 2.66173421e-01,  4.52459628e-01, -3.33769930e-02,
#          1.46047108e-01,  2.10456753e-01,  2.36847884e-01,
#         -4.22455606e-01,  4.03542728e+00,  1.92388762e-02,
#         -1.40759344e-02,  8.97925241e-02, -3.67553209e-02,
#          6.56503290e-02,  3.46123835e-01],
#        [-1.23359712e-01,  5.74248936e-01, -2.66966400e-02,
#          3.73349475e-01,  2.30218367e-01,  2.19930054e-01,
#         -1.37864714e-01, -2.24191653e-01,  1.02810243e-01,
#          4.16437379e-01,  5.53741776e-01, -8.67707946e-01,
#          2.52561135e-02,  1.17402245e+00]])

# %%
cluster_model_scaled.labels_
# Out:
# array([1, 1, 1, ..., 1, 4, 2], dtype=int32)

# %%
cluster_scaled_df['cluster_sc']=cluster_model_scaled.labels_

# %%
cluster_scaled_df['cluster_sc'].value_counts()
# Out:
# 1    354
# 4    241
# 0    222
# 2    172
# 3     49
# Name: cluster_sc, dtype: int64

# %%
cluster_scaled_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         0.395849 -0.297509  1.017337  0.605652  0.655555    -0.221964
# 1         0.778898  0.824874 -1.473872  0.703658  0.655555     0.679276
# 2         0.230612 -0.319409 -0.920270 -1.024181  0.655555    -0.524967
# 3         0.433403 -0.806687 -0.366668 -0.370510  0.655555    -0.377350
# 4        -0.460378  0.326646 -0.366668  0.386863  0.655555    -0.506839
# ...            ...       ...       ...       ...       ...          ...
# 1033     -1.339137  1.449028  1.017337  0.102436  0.655555     0.189809
# 1034     -0.542996  0.080269  1.570939 -0.158913  0.655555    -0.113194
# 1035     -0.820895  0.551122 -0.366668 -0.069599  0.655555    -0.338504
# 1036     -0.137415  1.262877  1.017337  0.644615 -1.525426     0.355554
# 1037      0.981689 -0.861437  1.570939 -0.906994  0.655555    -0.211605
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0        -0.834617         -0.334815 -0.530878  0.278454  0.391429
# 1        -0.825154          0.064007 -0.854350  0.537633 -0.037437
# 2        -0.466612         -0.076613 -0.453541 -0.086155 -0.457730
# 3         0.239958         -0.292340 -0.386291  0.423419 -0.307553
# 4        -0.553882         -0.335394 -0.480441 -0.288227 -1.103585
# ...            ...               ...       ...       ...       ...
# 1033     -0.827257         -0.218547 -0.204717 -0.345335  0.318832
# 1034     -0.577539         -0.335511 -0.520118  0.792420  0.200076
# 1035     -0.865424         -0.335422  0.622456 -0.086155  0.855813
# 1036     -0.631688          0.223026 -0.594766  0.291632  0.153156
# 1037      0.555390         -0.210662 -0.426641 -1.114088 -0.317900
#
#       duration_ms  time_signature  cluster_sc
# 0        1.033764         0.06565           1
# 1        0.138089         0.06565           1
# 2        0.068207         0.06565           1
# 3       -0.584953         0.06565           1
# 4        0.131923         0.06565           1
# ...           ...             ...         ...
# 1033    -1.990136         0.06565           4
# 1034    -1.292906         0.06565           4
# 1035    -0.279389         0.06565           1
# 1036    -1.094683         0.06565           4
# 1037    -0.296740         0.06565           2
#
# [1038 rows x 14 columns]

# %%
plt.scatter(cluster_scaled_df.iloc[:,0], cluster_scaled_df.iloc[:,1], cluster_scaled_df.iloc[:,2], cluster_scaled_df.iloc[:,3]);

# %%
cluster_scaled_df=cluster_scaled_df.drop('cluster_sc',axis=1)

# %%
K=range(5,18)
inertia=[]
for k in K:
    kmeans=KMeans(n_clusters=k,random_state=5)
    kmeans.fit(cluster_scaled_df)
    inertia.append(kmeans.inertia_)

# %%
#plot the resulting inertia - elbow 
plt.figure(figsize=(16,8))
plt.plot(K,inertia,'bx-')
plt.xlabel('k=noofclusters')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('elbow method inertia to find optimal K');

# %%
K=range(5,18)
sil=[]
for k in K:
    kmeans=KMeans(n_clusters=k,random_state=5)
    kmeans.fit(cluster_scaled_df)
    sil.append(silhouette_score(cluster_scaled_df,kmeans.predict(cluster_scaled_df)))

# %%
plt.figure(figsize=(16,8))
plt.plot(K,sil,'bo-')
plt.xlabel('k=noofclusters')
plt.ylabel('silhouette')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('silhouette score');

# %%
# We choose the K = 10 to redo the cluster

# %%
kmeans=KMeans(n_clusters=9, random_state=5)
ClMo=kmeans.fit(cluster_scaled_df)
cluster_scaled_df['cluster_final']=ClMo.labels_
cluster_scaled_df['cluster_final'].value_counts()
# Out:
# 1    345
# 8    214
# 2    169
# 3    155
# 4     54
# 5     48
# 0     43
# 6      9
# 7      1
# Name: cluster_final, dtype: int64

# %%
cluster_scaled_df
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0         0.395849 -0.297509  1.017337  0.605652  0.655555    -0.221964
# 1         0.778898  0.824874 -1.473872  0.703658  0.655555     0.679276
# 2         0.230612 -0.319409 -0.920270 -1.024181  0.655555    -0.524967
# 3         0.433403 -0.806687 -0.366668 -0.370510  0.655555    -0.377350
# 4        -0.460378  0.326646 -0.366668  0.386863  0.655555    -0.506839
# ...            ...       ...       ...       ...       ...          ...
# 1033     -1.339137  1.449028  1.017337  0.102436  0.655555     0.189809
# 1034     -0.542996  0.080269  1.570939 -0.158913  0.655555    -0.113194
# 1035     -0.820895  0.551122 -0.366668 -0.069599  0.655555    -0.338504
# 1036     -0.137415  1.262877  1.017337  0.644615 -1.525426     0.355554
# 1037      0.981689 -0.861437  1.570939 -0.906994  0.655555    -0.211605
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0        -0.834617         -0.334815 -0.530878  0.278454  0.391429
# 1        -0.825154          0.064007 -0.854350  0.537633 -0.037437
# 2        -0.466612         -0.076613 -0.453541 -0.086155 -0.457730
# 3         0.239958         -0.292340 -0.386291  0.423419 -0.307553
# 4        -0.553882         -0.335394 -0.480441 -0.288227 -1.103585
# ...            ...               ...       ...       ...       ...
# 1033     -0.827257         -0.218547 -0.204717 -0.345335  0.318832
# 1034     -0.577539         -0.335511 -0.520118  0.792420  0.200076
# 1035     -0.865424         -0.335422  0.622456 -0.086155  0.855813
# 1036     -0.631688          0.223026 -0.594766  0.291632  0.153156
# 1037      0.555390         -0.210662 -0.426641 -1.114088 -0.317900
#
#       duration_ms  time_signature  cluster_final
# 0        1.033764         0.06565              1
# 1        0.138089         0.06565              1
# 2        0.068207         0.06565              1
# 3       -0.584953         0.06565              1
# 4        0.131923         0.06565              1
# ...           ...             ...            ...
# 1033    -1.990136         0.06565              2
# 1034    -1.292906         0.06565              1
# 1035    -0.279389         0.06565              2
# 1036    -1.094683         0.06565              8
# 1037    -0.296740         0.06565              3
#
# [1038 rows x 14 columns]

# %%
playlist_features
# Out:
#                                      title               artist  \
# 0                             Original Sin                 INXS
# 1                                 Sussudio         Phil Collins
# 2              Don't You (Forget About Me)         Simple Minds
# 3                               Everywhere        Fleetwood Mac
# 4                               High & Dry                  ABC
# ...                                    ...                  ...
# 1033  If I Should Fall From Grace With God           The Pogues
# 1034                The Devil's Right Hand          Steve Earle
# 1035                 Europe After the Rain            John Foxx
# 1036            That's What You Always Say  The Dream Syndicate
# 1037   I'm In Love With A German Film Star         The Passions
#
#                      song_id  danceability  energy  key  loudness  mode  \
# 0     7pSzRRMaPXA39wvrnvdmSH         0.685   0.633    9    -7.259     1
# 1     07zkNvtcmPOFlMOXbma13k         0.736   0.838    0    -6.932     1
# 2     603aPXFY2Ec2WuFganUGuD         0.663   0.629    2   -12.697     1
# 3     6i8ecOsx4J2Px1maiqzqoG         0.690   0.540    4   -10.516     1
# 4     7oWqXVRExRlNR0jZJNoO9w         0.571   0.747    4    -7.989     1
# ...                      ...           ...     ...  ...       ...   ...
# 1033  2QlYQQ8JpZf8mAk7PWcXsB         0.454   0.952    9    -8.938     1
# 1034  59JOneFVktVPSm0agaQWDo         0.560   0.702   11    -9.810     1
# 1035  7p1wyDdcnJuwQDodZh1Duq         0.523   0.788    4    -9.512     1
# 1036  7jgfLVXTBxufrbccakHQi1         0.614   0.918    9    -7.129     0
# 1037  2pzc7K0AdUySB4V0SFMENJ         0.763   0.530   11   -12.306     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0377       0.01360          0.000106    0.0935    0.731  131.397
# 1          0.0725       0.01540          0.060800    0.0454    0.790  121.242
# 2          0.0260       0.08360          0.039400    0.1050    0.648  111.290
# 3          0.0317       0.21800          0.006570    0.1150    0.764  114.846
# 4          0.0267       0.06700          0.000018    0.1010    0.602   95.997
# ...           ...           ...               ...       ...      ...      ...
# 1033       0.0536       0.01500          0.017800    0.1420    0.589  129.678
# 1034       0.0419       0.06250          0.000000    0.0951    0.848  126.866
# 1035       0.0332       0.00774          0.000014    0.2650    0.648  142.393
# 1036       0.0600       0.05220          0.085000    0.0840    0.734  125.755
# 1037       0.0381       0.27800          0.019000    0.1090    0.414  114.601
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:7pSzRRMaPXA39wvrnvdmSH
# 1     audio_features  spotify:track:07zkNvtcmPOFlMOXbma13k
# 2     audio_features  spotify:track:603aPXFY2Ec2WuFganUGuD
# 3     audio_features  spotify:track:6i8ecOsx4J2Px1maiqzqoG
# 4     audio_features  spotify:track:7oWqXVRExRlNR0jZJNoO9w
# ...              ...                                   ...
# 1033  audio_features  spotify:track:2QlYQQ8JpZf8mAk7PWcXsB
# 1034  audio_features  spotify:track:59JOneFVktVPSm0agaQWDo
# 1035  audio_features  spotify:track:7p1wyDdcnJuwQDodZh1Duq
# 1036  audio_features  spotify:track:7jgfLVXTBxufrbccakHQi1
# 1037  audio_features  spotify:track:2pzc7K0AdUySB4V0SFMENJ
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7pSzRRMaPXA3...
# 1     https://api.spotify.com/v1/tracks/07zkNvtcmPOF...
# 2     https://api.spotify.com/v1/tracks/603aPXFY2Ec2...
# 3     https://api.spotify.com/v1/tracks/6i8ecOsx4J2P...
# 4     https://api.spotify.com/v1/tracks/7oWqXVRExRlN...
# ...                                                 ...
# 1033  https://api.spotify.com/v1/tracks/2QlYQQ8JpZf8...
# 1034  https://api.spotify.com/v1/tracks/59JOneFVktVP...
# 1035  https://api.spotify.com/v1/tracks/7p1wyDdcnJuw...
# 1036  https://api.spotify.com/v1/tracks/7jgfLVXTBxuf...
# 1037  https://api.spotify.com/v1/tracks/2pzc7K0AdUyS...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7pSz...       317240
# 1     https://api.spotify.com/v1/audio-analysis/07zk...       264947
# 2     https://api.spotify.com/v1/audio-analysis/603a...       260867
# 3     https://api.spotify.com/v1/audio-analysis/6i8e...       222733
# 4     https://api.spotify.com/v1/audio-analysis/7oWq...       264587
# ...                                                 ...          ...
# 1033  https://api.spotify.com/v1/audio-analysis/2QlY...       140693
# 1034  https://api.spotify.com/v1/audio-analysis/59JO...       181400
# 1035  https://api.spotify.com/v1/audio-analysis/7p1w...       240573
# 1036  https://api.spotify.com/v1/audio-analysis/7jgf...       192973
# 1037  https://api.spotify.com/v1/audio-analysis/2pzc...       239560
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1033               4
# 1034               4
# 1035               4
# 1036               4
# 1037               4
#
# [1038 rows x 20 columns]

# %%
playlist_names=playlist_features[['title','artist','song_id']]
cluster_final=cluster_scaled_df['cluster_final']
playlist_cluster=playlist_names.join(cluster_final)
playlist_cluster
# Out:
#                                      title               artist  \
# 0                             Original Sin                 INXS
# 1                                 Sussudio         Phil Collins
# 2              Don't You (Forget About Me)         Simple Minds
# 3                               Everywhere        Fleetwood Mac
# 4                               High & Dry                  ABC
# ...                                    ...                  ...
# 1033  If I Should Fall From Grace With God           The Pogues
# 1034                The Devil's Right Hand          Steve Earle
# 1035                 Europe After the Rain            John Foxx
# 1036            That's What You Always Say  The Dream Syndicate
# 1037   I'm In Love With A German Film Star         The Passions
#
#                      song_id  cluster_final
# 0     7pSzRRMaPXA39wvrnvdmSH              1
# 1     07zkNvtcmPOFlMOXbma13k              1
# 2     603aPXFY2Ec2WuFganUGuD              1
# 3     6i8ecOsx4J2Px1maiqzqoG              1
# 4     7oWqXVRExRlNR0jZJNoO9w              1
# ...                      ...            ...
# 1033  2QlYQQ8JpZf8mAk7PWcXsB              2
# 1034  59JOneFVktVPSm0agaQWDo              1
# 1035  7p1wyDdcnJuwQDodZh1Duq              2
# 1036  7jgfLVXTBxufrbccakHQi1              8
# 1037  2pzc7K0AdUySB4V0SFMENJ              3
#
# [1038 rows x 4 columns]

# %%
playlist_cluster
# Out:
#                                      title               artist  \
# 0                             Original Sin                 INXS
# 1                                 Sussudio         Phil Collins
# 2              Don't You (Forget About Me)         Simple Minds
# 3                               Everywhere        Fleetwood Mac
# 4                               High & Dry                  ABC
# ...                                    ...                  ...
# 1033  If I Should Fall From Grace With God           The Pogues
# 1034                The Devil's Right Hand          Steve Earle
# 1035                 Europe After the Rain            John Foxx
# 1036            That's What You Always Say  The Dream Syndicate
# 1037   I'm In Love With A German Film Star         The Passions
#
#                      song_id  cluster_final
# 0     7pSzRRMaPXA39wvrnvdmSH              1
# 1     07zkNvtcmPOFlMOXbma13k              1
# 2     603aPXFY2Ec2WuFganUGuD              1
# 3     6i8ecOsx4J2Px1maiqzqoG              1
# 4     7oWqXVRExRlNR0jZJNoO9w              1
# ...                      ...            ...
# 1033  2QlYQQ8JpZf8mAk7PWcXsB              2
# 1034  59JOneFVktVPSm0agaQWDo              1
# 1035  7p1wyDdcnJuwQDodZh1Duq              2
# 1036  7jgfLVXTBxufrbccakHQi1              8
# 1037  2pzc7K0AdUySB4V0SFMENJ              3
#
# [1038 rows x 4 columns]

# %%
from IPython.display import display

input_song= input('what song do you like?\n\n ')
lower_song=input_song.lower()

df = songs.applymap(lambda s:s.lower() if type(s) == str else s)

if lower_song in df['Song_title'].values:
    print ('\nCongrats! This is a hot song from the Billboard Top 100')
    
elif lower_song in playlist_cluster_lower['title'].values: 
    print('''\nThis is not a hot song or does not match with the Billboard Top 100, 
    but we have found some songs from a Spotify list based 
    in the genre of the song you selected!\n''')
    
    playlist_cluster_lower = playlist_cluster.applymap(lambda s:s.lower() if type(s) == str else s)
    prova=playlist_cluster_lower.query("title == @input_song")
    print(prova)
    
else:
    print('\nSorry! We can not find the song you are looking for' )
# Out:
# what song do you like?
#
#  Anti-hero
#
# Congrats! This is a hot song from the Billboard Top 100

# %%
#     track_id = sp.search(q='track:' + lower_song, type='track', limit=1)
#     x = track_id["tracks"]['items'][0]['id']
#     audio_feat=pd.DataFrame(sp.audio_features(tracks=x))
#     audio_feat
