# %%
from bs4 import BeautifulSoup
import re 
import requests
import pandas as pd
from tqdm.notebook import tqdm
import random
from random import randint
import warnings
warnings.filterwarnings("ignore")

# %%
url = "https://www.billboard.com/charts/hot-100"
# downloading  html with a get request
response = requests.get(url)
# check response status code 
response.status_code
# Out:
# 200

# %%
billboardsoup = BeautifulSoup(response.content, 'html.parser')

# %%
top_100 = len(billboardsoup.select('h3.c-title.a-no-trucate'))
song = []
artist = []

for i in tqdm(range(top_100)):
    song.append(billboardsoup.select('h3.c-title.a-no-trucate')[i].get_text(strip=True))
    artist.append(billboardsoup.select('span.c-label.a-font-primary-s')[i].get_text(strip=True))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
billboard_top100 = pd.DataFrame({'song':song,'artist':artist})

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass
import pprint

# %%
client_id = str(getpass.getpass('client_id: '))
client_secret = str(getpass.getpass('client_secret: '))
# embedding getpass credentials in the access key
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id = client_id, client_secret = client_secret))
# Out:
# client_id: ········
# client_secret: ········

# %%
first_playlist = sp.user_playlist_tracks("solitude collective", "1IEQ8C3G1qT0W80muYgROT")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
first_results = get_tracks("solitude collective", "1IEQ8C3G1qT0W80muYgROT")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = first_results
for r in first_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[199:299]))
features_info4 = pd.DataFrame(sp.audio_features(tracks = song_id[299:399]))
features_info5 = pd.DataFrame(sp.audio_features(tracks = song_id[399:]))
features = pd.concat([features_info, features_info2, features_info3, features_info4, features_info5])
features.reset_index(drop=True, inplace=True)

# %%
first_playlist = pd.concat([playlist_info, features], axis=1)
first_playlist.reset_index()
# Out:
#      index                         song_name                 song_id  \
# 0        0              Carry on Wayward Son  2SUpC3UgKwLVOS2FtZif9N
# 1        1                              Jump  2PfBSkCKZDXMsJogMT0wML
# 2        2         Rock You Like A Hurricane  0XIvZ82aDF7JiSi3ZE320u
# 3        3                     Back In Black  08mG3Y1vljYA6bvDt4Wqkj
# 4        4                       Hot Blooded  6xMHglHoafdDFGXS6qfwSH
# ..     ...                               ...                     ...
# 423    423  I'd Be Lost If It Wasn't for You  64FhrwziLZYXXTtmhgk9Xh
# 424    424                          My Curse  6zKF4293k44ItKWJJgrhXv
# 425    425                Livin' On A Prayer  7qQnBfwXrw2tZNFG4Uf57N
# 426    426        Touch-A, Touch-A, Touch Me  2SK1kGbpABI9EyUbADSP5z
# 427    427              Ashes The Rain And I  2yyikdfuzFFJQuqnDpOBi6
#
#                 artist  danceability  energy  key  loudness  mode  \
# 0               Kansas         0.452   0.788    7    -5.712     1
# 1            Van Halen         0.547   0.822    0    -7.201     1
# 2            Scorpions         0.482   0.601    7   -12.846     1
# 3                AC/DC         0.310   0.700    9    -5.678     1
# 4            Foreigner         0.705   0.806    0    -4.830     1
# ..                 ...           ...     ...  ...       ...   ...
# 423       Elijah Honey         0.639   0.743    5    -7.198     1
# 424  Killswitch Engage         0.197   0.956   10    -2.908     0
# 425           Bon Jovi         0.520   0.887    0    -3.296     1
# 426     Susan Sarandon         0.355   0.351    1   -13.572     1
# 427         James Gang         0.349   0.413    2   -12.625     0
#
#      speechiness  ...  liveness  valence    tempo            type  \
# 0         0.0326  ...    0.4410   0.7930  126.739  audio_features
# 1         0.0292  ...    0.0645   0.7740  130.138  audio_features
# 2         0.0486  ...    0.2490   0.7740  125.619  audio_features
# 3         0.0470  ...    0.0828   0.7630  188.386  audio_features
# 4         0.0814  ...    0.0676   0.7630  117.945  audio_features
# ..           ...  ...       ...      ...      ...             ...
# 423       0.0527  ...    0.3950   0.8490  120.415  audio_features
# 424       0.0663  ...    0.2610   0.2090  177.018  audio_features
# 425       0.0349  ...    0.1860   0.7930  122.528  audio_features
# 426       0.0621  ...    0.1090   0.4310  171.896  audio_features
# 427       0.0324  ...    0.4840   0.0538  107.284  audio_features
#
#                          id                                   uri  \
# 0    2SUpC3UgKwLVOS2FtZif9N  spotify:track:2SUpC3UgKwLVOS2FtZif9N
# 1    2PfBSkCKZDXMsJogMT0wML  spotify:track:2PfBSkCKZDXMsJogMT0wML
# 2    0XIvZ82aDF7JiSi3ZE320u  spotify:track:0XIvZ82aDF7JiSi3ZE320u
# 3    08mG3Y1vljYA6bvDt4Wqkj  spotify:track:08mG3Y1vljYA6bvDt4Wqkj
# 4    6xMHglHoafdDFGXS6qfwSH  spotify:track:6xMHglHoafdDFGXS6qfwSH
# ..                      ...                                   ...
# 423  64FhrwziLZYXXTtmhgk9Xh  spotify:track:64FhrwziLZYXXTtmhgk9Xh
# 424  6zKF4293k44ItKWJJgrhXv  spotify:track:6zKF4293k44ItKWJJgrhXv
# 425  7qQnBfwXrw2tZNFG4Uf57N  spotify:track:7qQnBfwXrw2tZNFG4Uf57N
# 426  2SK1kGbpABI9EyUbADSP5z  spotify:track:2SK1kGbpABI9EyUbADSP5z
# 427  2yyikdfuzFFJQuqnDpOBi6  spotify:track:2yyikdfuzFFJQuqnDpOBi6
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2SUpC3UgKwLV...
# 1    https://api.spotify.com/v1/tracks/2PfBSkCKZDXM...
# 2    https://api.spotify.com/v1/tracks/0XIvZ82aDF7J...
# 3    https://api.spotify.com/v1/tracks/08mG3Y1vljYA...
# 4    https://api.spotify.com/v1/tracks/6xMHglHoafdD...
# ..                                                 ...
# 423  https://api.spotify.com/v1/tracks/64FhrwziLZYX...
# 424  https://api.spotify.com/v1/tracks/6zKF4293k44I...
# 425  https://api.spotify.com/v1/tracks/7qQnBfwXrw2t...
# 426  https://api.spotify.com/v1/tracks/2SK1kGbpABI9...
# 427  https://api.spotify.com/v1/tracks/2yyikdfuzFFJ...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2SUp...      322093
# 1    https://api.spotify.com/v1/audio-analysis/2PfB...      239560
# 2    https://api.spotify.com/v1/audio-analysis/0XIv...      252493
# 3    https://api.spotify.com/v1/audio-analysis/08mG...      255493
# 4    https://api.spotify.com/v1/audio-analysis/6xMH...      268693
# ..                                                 ...         ...
# 423  https://api.spotify.com/v1/audio-analysis/64Fh...      181893
# 424  https://api.spotify.com/v1/audio-analysis/6zKF...      244773
# 425  https://api.spotify.com/v1/audio-analysis/7qQn...      250627
# 426  https://api.spotify.com/v1/audio-analysis/2SK1...      151922
# 427  https://api.spotify.com/v1/audio-analysis/2yyi...      290627
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 423              4
# 424              3
# 425              4
# 426              4
# 427              4
#
# [428 rows x 22 columns]

# %%
second_playlist = sp.user_playlist_tracks("Spotify", "37i9dQZF1DX4UtSsGT1Sbe")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
second_results = get_tracks("Spotify", "37i9dQZF1DX4UtSsGT1Sbe")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = second_results
for r in second_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist2_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features2_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features2_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:]))
features2 = pd.concat([features2_info, features2_info2])
features2.reset_index(drop=True, inplace=True)

# %%
second_playlist = pd.concat([playlist2_info, features2], axis=1)
second_playlist.reset_index()
# Out:
#      index                                   song_name  \
# 0        0  I Wanna Dance with Somebody (Who Loves Me)
# 1        1                                 Billie Jean
# 2        2                             Time After Time
# 3        3                                  Take on Me
# 4        4     Footloose - From "Footloose" Soundtrack
# ..     ...                                         ...
# 145    145                    I'm Gonna Be (500 Miles)
# 146    146                                 Missing You
# 147    147                              Sexual Healing
# 148    148                                Golden Brown
# 149    149                                Black Velvet
#
#                     song_id           artist  danceability  energy  key  \
# 0    2tUBqZG2AbRi7Q0BIrVrEj  Whitney Houston         0.709   0.824    1
# 1    5ChkMS8OtdzJeqyybCc9R5  Michael Jackson         0.920   0.654   11
# 2    1Jj6MF0xDOMA3Ut2Z368Bx     Cyndi Lauper         0.724   0.436    0
# 3    2WfaOiMkCvy7F5fcp2zZ8L             a-ha         0.573   0.902    6
# 4    2vz1CsL5WBsbpBcwgboTAw    Kenny Loggins         0.583   0.905    2
# ..                      ...              ...           ...     ...  ...
# 145  66S14BkJDxgkYxLl5DCqOz  The Proclaimers         0.851   0.551    4
# 146  1Qrdlkgg9I4J7r3P4kZNwr       John Waite         0.552   0.552   11
# 147  3VZmChrnVW8JK6ano4gSED      Marvin Gaye         0.805   0.602    0
# 148  2AX5E86cn9n2dgioZEjirI   The Stranglers         0.562   0.383    6
# 149  1KU5EHSz04JhGg3rReGJ0N    Alannah Myles         0.754   0.366    8
#
#      loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0      -8.824     1       0.0453  ...    0.0888    0.867  118.818
# 1      -3.051     0       0.0401  ...    0.0360    0.847  117.046
# 2      -9.321     1       0.0282  ...    0.0908    0.324  130.439
# 3      -7.638     0       0.0540  ...    0.0928    0.876   84.412
# 4      -6.132     1       0.0733  ...    0.0593    0.646  173.982
# ..        ...   ...          ...  ...       ...      ...      ...
# 145    -5.177     1       0.0396  ...    0.0827    0.807  131.922
# 146    -9.736     0       0.0364  ...    0.0460    0.593  208.571
# 147    -9.700     0       0.0579  ...    0.0581    0.744   94.382
# 148   -15.474     1       0.0304  ...    0.1380    0.599   93.764
# 149   -10.070     1       0.0312  ...    0.1060    0.469   91.147
#
#                type                      id  \
# 0    audio_features  2tUBqZG2AbRi7Q0BIrVrEj
# 1    audio_features  5ChkMS8OtdzJeqyybCc9R5
# 2    audio_features  1Jj6MF0xDOMA3Ut2Z368Bx
# 3    audio_features  2WfaOiMkCvy7F5fcp2zZ8L
# 4    audio_features  2vz1CsL5WBsbpBcwgboTAw
# ..              ...                     ...
# 145  audio_features  66S14BkJDxgkYxLl5DCqOz
# 146  audio_features  1Qrdlkgg9I4J7r3P4kZNwr
# 147  audio_features  3VZmChrnVW8JK6ano4gSED
# 148  audio_features  2AX5E86cn9n2dgioZEjirI
# 149  audio_features  1KU5EHSz04JhGg3rReGJ0N
#
#                                       uri  \
# 0    spotify:track:2tUBqZG2AbRi7Q0BIrVrEj
# 1    spotify:track:5ChkMS8OtdzJeqyybCc9R5
# 2    spotify:track:1Jj6MF0xDOMA3Ut2Z368Bx
# 3    spotify:track:2WfaOiMkCvy7F5fcp2zZ8L
# 4    spotify:track:2vz1CsL5WBsbpBcwgboTAw
# ..                                    ...
# 145  spotify:track:66S14BkJDxgkYxLl5DCqOz
# 146  spotify:track:1Qrdlkgg9I4J7r3P4kZNwr
# 147  spotify:track:3VZmChrnVW8JK6ano4gSED
# 148  spotify:track:2AX5E86cn9n2dgioZEjirI
# 149  spotify:track:1KU5EHSz04JhGg3rReGJ0N
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2tUBqZG2AbRi...
# 1    https://api.spotify.com/v1/tracks/5ChkMS8OtdzJ...
# 2    https://api.spotify.com/v1/tracks/1Jj6MF0xDOMA...
# 3    https://api.spotify.com/v1/tracks/2WfaOiMkCvy7...
# 4    https://api.spotify.com/v1/tracks/2vz1CsL5WBsb...
# ..                                                 ...
# 145  https://api.spotify.com/v1/tracks/66S14BkJDxgk...
# 146  https://api.spotify.com/v1/tracks/1Qrdlkgg9I4J...
# 147  https://api.spotify.com/v1/tracks/3VZmChrnVW8J...
# 148  https://api.spotify.com/v1/tracks/2AX5E86cn9n2...
# 149  https://api.spotify.com/v1/tracks/1KU5EHSz04Jh...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2tUB...      291293
# 1    https://api.spotify.com/v1/audio-analysis/5Chk...      293827
# 2    https://api.spotify.com/v1/audio-analysis/1Jj6...      243067
# 3    https://api.spotify.com/v1/audio-analysis/2Wfa...      225280
# 4    https://api.spotify.com/v1/audio-analysis/2vz1...      226827
# ..                                                 ...         ...
# 145  https://api.spotify.com/v1/audio-analysis/66S1...      219467
# 146  https://api.spotify.com/v1/audio-analysis/1Qrd...      269760
# 147  https://api.spotify.com/v1/audio-analysis/3VZm...      238600
# 148  https://api.spotify.com/v1/audio-analysis/2AX5...      206760
# 149  https://api.spotify.com/v1/audio-analysis/1KU5...      287440
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 145              4
# 146              4
# 147              4
# 148              3
# 149              4
#
# [150 rows x 22 columns]

# %%
third_playlist = sp.user_playlist_tracks("Peter Nordestgaard", "0lNwm5xFEgRx4iDP2DLx3j")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
third_results = get_tracks("Peter Nordestgaard", "0lNwm5xFEgRx4iDP2DLx3j")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = third_results
for r in third_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist3_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features3_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features3_info1 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features3_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[199:299]))
features3_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[299:399]))
features3_info4 = pd.DataFrame(sp.audio_features(tracks = song_id[399:499]))
features3_info5 = pd.DataFrame(sp.audio_features(tracks = song_id[499:599]))
features3_info6 = pd.DataFrame(sp.audio_features(tracks = song_id[599:699]))
features3_info7 = pd.DataFrame(sp.audio_features(tracks = song_id[699:799]))
features3_info8 = pd.DataFrame(sp.audio_features(tracks = song_id[799:899]))
features3_info9 = pd.DataFrame(sp.audio_features(tracks = song_id[899:999]))
features3_info10 = pd.DataFrame(sp.audio_features(tracks = song_id[999:]))
features3 = pd.concat([features3_info, features3_info1, features3_info2, features3_info3, features3_info4, features3_info5, features3_info6, features3_info7, features3_info8, features3_info9, features3_info10])
features3.reset_index(drop=True, inplace=True)

# %%
third_playlist = pd.concat([playlist3_info, features3_info], axis=1)
third_playlist.reset_index()
# Out:
#      index                                song_name                 song_id  \
# 0        0                Imagine - Remastered 2010  7pKfPomDEeI4TPT6EOYjn9
# 1        1                   A Whiter Shade Of Pale  3qitymULqEibr7yknRMKU4
# 2        2                            My Sweet Lord  1chu8wc9zbNqTQ2ahROys1
# 3        3  God Only Knows - Mono / 1997 Remastered  6iGU74CwXuT4XVepjc9Emf
# 4        4               Bridge Over Troubled Water  6l8EbYRtQMgKOyc1gcDHF9
# ..     ...                                      ...                     ...
# 995    995                        She Will Be Loved  7sapKrjDij2fpDVj0GxP66
# 996    996                        Achy Breaky Heart  2EoIt9vdgFRNW03u5IvFsQ
# 997    997                              Reet Petite  3h4udS0WeWbsur3yfjvnm4
# 998    998          All I Want for Christmas Is You  0bYg9bo50gSsH3LtXe2SQn
# 999    999                               In the End  7q115ia4fQn9zonjpexWsY
#
#                 artist  danceability  energy  key  loudness  mode  \
# 0          John Lennon         0.547   0.257  0.0   -12.358   1.0
# 1         Procol Harum         0.249   0.660  0.0    -6.905   1.0
# 2      George Harrison         0.537   0.685  1.0    -8.935   0.0
# 3       The Beach Boys         0.521   0.487  6.0    -7.525   0.0
# 4    Simon & Garfunkel         0.149   0.206  3.0   -13.888   1.0
# ..                 ...           ...     ...  ...       ...   ...
# 995           Maroon 5           NaN     NaN  NaN       NaN   NaN
# 996    Billy Ray Cyrus           NaN     NaN  NaN       NaN   NaN
# 997      Jackie Wilson           NaN     NaN  NaN       NaN   NaN
# 998       Mariah Carey           NaN     NaN  NaN       NaN   NaN
# 999        Linkin Park           NaN     NaN  NaN       NaN   NaN
#
#      speechiness  ...  liveness  valence    tempo            type  \
# 0         0.0252  ...    0.0935    0.169   75.752  audio_features
# 1         0.0342  ...    0.0891    0.435  149.813  audio_features
# 2         0.0333  ...    0.0839    0.542  120.965  audio_features
# 3         0.0299  ...    0.0579    0.483  117.072  audio_features
# 4         0.0323  ...    0.1150    0.264   79.764  audio_features
# ..           ...  ...       ...      ...      ...             ...
# 995          NaN  ...       NaN      NaN      NaN             NaN
# 996          NaN  ...       NaN      NaN      NaN             NaN
# 997          NaN  ...       NaN      NaN      NaN             NaN
# 998          NaN  ...       NaN      NaN      NaN             NaN
# 999          NaN  ...       NaN      NaN      NaN             NaN
#
#                          id                                   uri  \
# 0    7pKfPomDEeI4TPT6EOYjn9  spotify:track:7pKfPomDEeI4TPT6EOYjn9
# 1    3qitymULqEibr7yknRMKU4  spotify:track:3qitymULqEibr7yknRMKU4
# 2    1chu8wc9zbNqTQ2ahROys1  spotify:track:1chu8wc9zbNqTQ2ahROys1
# 3    6iGU74CwXuT4XVepjc9Emf  spotify:track:6iGU74CwXuT4XVepjc9Emf
# 4    6l8EbYRtQMgKOyc1gcDHF9  spotify:track:6l8EbYRtQMgKOyc1gcDHF9
# ..                      ...                                   ...
# 995                     NaN                                   NaN
# 996                     NaN                                   NaN
# 997                     NaN                                   NaN
# 998                     NaN                                   NaN
# 999                     NaN                                   NaN
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/7pKfPomDEeI4...
# 1    https://api.spotify.com/v1/tracks/3qitymULqEib...
# 2    https://api.spotify.com/v1/tracks/1chu8wc9zbNq...
# 3    https://api.spotify.com/v1/tracks/6iGU74CwXuT4...
# 4    https://api.spotify.com/v1/tracks/6l8EbYRtQMgK...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/7pKf...    187867.0
# 1    https://api.spotify.com/v1/audio-analysis/3qit...    248947.0
# 2    https://api.spotify.com/v1/audio-analysis/1chu...    281227.0
# 3    https://api.spotify.com/v1/audio-analysis/6iGU...    173040.0
# 4    https://api.spotify.com/v1/audio-analysis/6l8E...    293120.0
# ..                                                 ...         ...
# 995                                                NaN         NaN
# 996                                                NaN         NaN
# 997                                                NaN         NaN
# 998                                                NaN         NaN
# 999                                                NaN         NaN
#
#     time_signature
# 0              4.0
# 1              4.0
# 2              4.0
# 3              4.0
# 4              4.0
# ..             ...
# 995            NaN
# 996            NaN
# 997            NaN
# 998            NaN
# 999            NaN
#
# [1000 rows x 22 columns]

# %%
fourth_playlist = sp.user_playlist_tracks("Spotify", "37i9dQZF1DX2UXfvEIZvDK")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
fourth_results = get_tracks("Spotify", "37i9dQZF1DX2UXfvEIZvDK")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = fourth_results
for r in fourth_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist4_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features4_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:]))

# %%
fourth_playlist = pd.concat([playlist4_info, features4_info], axis=1)
fourth_playlist.reset_index()
# Out:
#     index                                          song_name  \
# 0       0                                        Scar Tissue
# 1       1                                           Santeria
# 2       2                                  Island In The Sun
# 3       3                                      Every Morning
# 4       4                                              WALLS
# 5       5                          Talk Tonight - Remastered
# 6       6                                     What It's Like
# 7       7                                     Way down We Go
# 8       8                                    Make It Wit Chu
# 9       9                         The Man Who Sold The World
# 10     10                                      The Scientist
# 11     11                                       No Surprises
# 12     12                   With Or Without You - Remastered
# 13     13                                  Hey There Delilah
# 14     14                            Wonderwall - Remastered
# 15     15                                            Fix You
# 16     16                  Good Riddance (Time of Your Life)
# 17     17                                          Renegades
# 18     18                                         I Miss You
# 19     19                                       Karma Police
# 20     20                                                One
# 21     21                                              Drive
# 22     22                                   Behind Blue Eyes
# 3    0.679    8    -4.496     1       0.0365  ...    0.0769   0.9750  109.916
# 4    0.320    8   -14.340     1       0.0313  ...    0.1100   0.1070   82.511
# 5    0.423    4    -8.499     0       0.0242  ...    0.3610   0.2990   85.213
# 6    0.557    0    -7.423     1       0.0281  ...    0.0866   0.4050   85.152
# 7    0.505   10    -8.022     0       0.1170  ...    0.1040   0.3370  163.255
# 8    0.811    9    -5.308     1       0.0277  ...    0.1300   0.5780   91.970
# 9    0.753    1    -8.937     0       0.0832  ...    0.2570   0.4200  115.102
# 10   0.442    5    -7.224     1       0.0243  ...    0.1100   0.2130  146.277
# 11   0.393    5   -10.654     1       0.0278  ...    0.1130   0.1180   76.426
# 12   0.429    2   -11.822     1       0.0285  ...    0.1410   0.1130  110.171
# 13   0.291    2   -10.572     1       0.0293  ...    0.1140   0.2980  103.971
# 14   0.893    2    -4.097     1       0.0406  ...    0.1870   0.4340  174.323
# 15   0.417    3    -8.740     1       0.0338  ...    0.1130   0.1240  138.178
# 16   0.432    7    -7.844     1       0.0302  ...    0.1610   0.6480   94.605
# 17   0.862    2    -6.003     1       0.0905  ...    0.2290   0.5280   90.052
# 18   0.714   11    -8.295     1       0.0450  ...    0.0855   0.5930  110.017
# 19   0.501    7    -9.129     1       0.0258  ...    0.1720   0.3240   74.807
# 20   0.534    0    -8.793     1       0.0369  ...    0.1550   0.3250  181.305
# 21   0.792    4    -7.340     0       0.0360  ...    0.1190   0.6660   90.565
# 22   0.489    7    -6.660     1       0.0271  ...    0.1190   0.0902  120.315
# 23   0.563    4    -6.607     1       0.0272  ...    0.1430   0.2090  137.715
# 24   0.200    8   -11.063     1       0.0311  ...    0.0897   0.1700   83.966
# 25   0.561    3   -10.059     0       0.0296  ...    0.0775   0.1590  136.136
# 26   0.394    4    -9.793     0       0.0262  ...    0.0795   0.1700  142.370
# 27   0.610    3    -2.695     0       0.0342  ...    0.1350   0.2140  123.762
# 28   0.348    0   -11.100     1       0.0288  ...    0.0823   0.2830  107.819
# 29   0.327   11   -10.835     0       0.0327  ...    0.1110   0.2980  161.858
# 30   0.774    6    -4.054     1       0.0338  ...    0.1430   0.0824  116.529
# 31   0.710    1    -7.445     1       0.0275  ...    0.1180   0.3780  119.989
# 32   0.474    4    -8.202     0       0.0271  ...    0.1170   0.3800  102.379
# 33   0.776    2    -8.042     1       0.0298  ...    0.1780   0.2820   98.986
# 34   0.629    0    -6.434     1       0.0335  ...    0.3690   0.2370   80.012
# 35   0.708    0   -10.419     1       0.0374  ...    0.1100   0.8460  130.970
# 36   0.493    7    -9.461     1       0.0284  ...    0.1010   0.1670   60.772
# 37   0.532    2    -6.467     1       0.0307  ...    0.0999   0.1220  103.992
# 38   0.245   11   -10.227     1       0.0344  ...    0.1190   0.2100  136.553
# 39   0.418    4   -10.205     0       0.0277  ...    0.1390   0.2180  129.516
# 40   0.520    0    -8.648     1       0.0261  ...    0.1540   0.1770   77.437
# 41   0.477    5    -7.528     0       0.0266  ...    0.1330   0.2270  129.014
# 42   0.594    1    -4.708     1       0.0262  ...    0.0752   0.2180  146.564
# 43   0.547    0    -6.846     1       0.0261  ...    0.1460   0.3050   73.396
# 44   0.709    0    -3.545     1       0.0260  ...    0.1310   0.3190   81.331
# 45   0.279    6   -11.586     0       0.0265  ...    0.1100   0.1620  139.362
# 46   0.747    6    -3.184     0       0.0339  ...    0.1200   0.2180  151.062
# 47   0.223    8    -8.237     0       0.0300  ...    0.0883   0.1790   81.414
# 48   0.331    9    -7.532     0       0.0288  ...    0.1720   0.1390  117.330
# 49   0.426    6    -6.961     1       0.0430  ...    0.0903   0.7890  184.866
# 50   0.382    2   -11.231     0       0.0566  ...    0.1100   0.5400  121.120
# 51   0.619    6    -9.047     1       0.0264  ...    0.1680   0.3250  128.967
# 52   0.559   10    -5.170     1       0.0270  ...    0.1930   0.4100  156.907
# 53   0.835    0    -4.448     1       0.0332  ...    0.1460   0.4440  145.885
# 54   0.333    6   -12.717     1       0.0324  ...    0.1510   0.0802  126.619
# 55   0.152    0   -14.579     1       0.0391  ...    0.1000   0.1120  105.500
# 56   0.543    2    -9.142     1       0.0296  ...    0.0964   0.1180  129.089
# 57   0.464    7    -8.543     1       0.0272  ...    0.0944   0.1480  144.222
# 58   0.593    4    -7.419     1       0.0241  ...    0.2160   0.6530  170.506
# 59   0.554    7    -5.668     1       0.0363  ...    0.0785   0.9780  137.013
#
#               type                      id  \
# 0   audio_features  1G391cbiT3v3Cywg8T7DM1
# 1   audio_features  2hnMS47jN0etwvFPzYk11f
# 2   audio_features  2MLHyLy5z5l5YRp7momlgw
# 3   audio_features  2ouURa1AIXp3AvkS52Jry5
# 4   audio_features  41QhRnFDdhMLtR8tmnolbr
# 5   audio_features  2LNV0347QKt4AHxRSfCBij
# 6   audio_features  6vUPPEN2V2lZ78b6DyEIjZ
# 7   audio_features  0y1QJc3SJVPKJ1OvFmFqe6
# 8   audio_features  0Cgd3CK6D2hhbwmLRvtscH
# 9   audio_features  15VRO9CQwMpbqUYA7e6Hwg
# 10  audio_features  75JFxkI2RXiU7L9VXzMkle
# 11  audio_features  10nyNJ6zNy2YVYLrcwLccB
# 12  audio_features  6ADSaE87h8Y3lccZlBJdXH
# 13  audio_features  4RCWB3V8V0dignt99LZ8vH
# 14  audio_features  7ygpwy2qP3NbrxVkHvUhXY
# 15  audio_features  7LVHVU3tWfcxj5aiPFEW4Q
# 16  audio_features  6ORqU0bHbVCRjXm9AjyHyZ
# 17  audio_features  0fYVliAYKHuPmECRs1pbRf
# 18  audio_features  1AdYZ6X00nXmO613Y7GJOl
# 19  audio_features  63OQupATfueTdZMWTxW03A
# 20  audio_features  3G69vJMWsX6ZohTykad2AU
# 21  audio_features  7nnWIPM5hwE3DaUBkvOIpy
# 22  audio_features  1MTQHCpraD4S8g5PAFKzoj
# 23  audio_features  7JIuqL4ZqkpfGKQhYlrirs
# 24  audio_features  3xXBsjrbG1xQIm1xv1cKOt
# 31  https://api.spotify.com/v1/audio-analysis/2UZt...      233173
# 32  https://api.spotify.com/v1/audio-analysis/7Gpr...      204960
# 33  https://api.spotify.com/v1/audio-analysis/6q4a...      363800
# 34  https://api.spotify.com/v1/audio-analysis/0sp0...      209307
# 35  https://api.spotify.com/v1/audio-analysis/6pb5...      132840
# 36  https://api.spotify.com/v1/audio-analysis/5lHg...      196187
# 37  https://api.spotify.com/v1/audio-analysis/6J0x...      271307
# 38  https://api.spotify.com/v1/audio-analysis/42Q0...      210447
# 39  https://api.spotify.com/v1/audio-analysis/6YIg...      196905
# 40  https://api.spotify.com/v1/audio-analysis/15kL...      304880
# 41  https://api.spotify.com/v1/audio-analysis/4sM7...      201200
# 42  https://api.spotify.com/v1/audio-analysis/50Re...      293133
# 43  https://api.spotify.com/v1/audio-analysis/0ZSm...      230880
# 44  https://api.spotify.com/v1/audio-analysis/6Hks...      248640
# 45  https://api.spotify.com/v1/audio-analysis/6kyx...      237027
# 46  https://api.spotify.com/v1/audio-analysis/4i4A...      249107
# 47  https://api.spotify.com/v1/audio-analysis/1YA7...      208213
# 48  https://api.spotify.com/v1/audio-analysis/5YFE...      178280
# 49  https://api.spotify.com/v1/audio-analysis/6Grr...      200067
# 50  https://api.spotify.com/v1/audio-analysis/3tlX...      173853
# 51  https://api.spotify.com/v1/audio-analysis/5UNo...      283973
# 52  https://api.spotify.com/v1/audio-analysis/20wn...      235947
# 53  https://api.spotify.com/v1/audio-analysis/5Ih4...      251631
# 54  https://api.spotify.com/v1/audio-analysis/1fPK...      250293
# 55  https://api.spotify.com/v1/audio-analysis/2fDV...      293453
# 56  https://api.spotify.com/v1/audio-analysis/5TxU...      318067
# 57  https://api.spotify.com/v1/audio-analysis/7Bz8...      240733
# 58  https://api.spotify.com/v1/audio-analysis/6qV3...      299253
# 59  https://api.spotify.com/v1/audio-analysis/2LGA...      156933
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
# 20              4
# 21              4
# 22              4
# 23              3
# 24              4
# 25              3
# 26              3
# 27              4
# 28              4
# 29              4
# 30              4
# 31              4
# 32              4
# 33              4
# 34              4
# 35              4
# 36              4
# 37              4
# 38              3
# 39              4
# 40              4
# 41              4
# 42              4
# 43              4
# 44              4
# 45              4
# 46              4
# 47              4
# 48              4
# 49              3
# 50              4
# 51              4
# 52              3
# 53              4
# 54              4
# 55              3
# 56              4
# 57              3
# 58              4
# 59              4
#
# [60 rows x 22 columns]

# %%
fifth_playlist = sp.user_playlist_tracks("Spotify", "37i9dQZF1DX8Md3JnnrexB")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
fifth_results = get_tracks("Spotify", "37i9dQZF1DX8Md3JnnrexB")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = fifth_results
for r in fifth_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist5_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features5_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:]))
# Out:
# HTTP Error for GET to https://api.spotify.com/v1
inop0EDd9ouwTaT1,7bmvCeN6JaeGN448OEGgLW,3tCLYifmzJhJHjUTTfPu0P,2f28m5YwEAh9aHOG14ajDD,2VUsmzlxjarwAVMCI2bm9x,31S04SZjQCMUTEIF9PWIEp,2zC0uKFfERvtOYNKendhEs,6HHlyBUx4YGVE95GF0orTe,5Jg9DV3m2umJpoHXV2e6j8,1FjyfUBL7Dj1GpSxL1XLCQ,1nrIaUgk4D5gI1yqQcsu3W,2PMW9aVSHvMwUC428yfDqx,1BDohKyV2EJ6iOmvx1K2FW,5LvUhG3juSj0TnCoHifKd7,19mXqYcLHY716cN53T1d1E,3hyp18EIQAjAFqVAMcpCQJ
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# /var/folders/vp/2wvfyb695rg5q5v9fgk55vpr0000gn/T/ipykernel_90094/2369058467.py in <module>
# ----> 1 features5_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:]))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in audio_features(self, tracks)
#    1690         else:
#    1691             tlist = [self._get_id("track", t) for t in tracks]
# -> 1692             results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1693         # the response has changed, look for the new style first, and if
#    1694         # its not there, fallback on the old style
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     265             )
#     266
# --> 267             raise SpotifyException(
#     268                 response.status_code,
#     269                 -1,
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/audio-features/?ids=1k1Bqnv2R0uJXQN4u6LKYt,745H5CctFr12Mo7cqa1BMH,3zBhihYUHBmGd2bcQIobrF,63xdwScd1Ai1GigAwQxE8y,1Omt5bfz1tZUCqd26HxbS0,3nFJbZCHP4d9vduKjJLdBL,49MHCPzvMLXhRjDantBMVH,3gsCAGsWr6pUm1Vy7CPPob,3l3xTXsUXeWlkPqzMs7mPD,7MF7QAodbGzNYav5ZfIhAY,3VZmChrnVW8JK6ano4gSED,0n2pjCIMKwHSXoYfEbYMfX,3M8FzayQWtkvOhqMn2V4T2,7jmHyHMEqm9MJWiMAneF05,5K09WxKdlkroDyEVyOSySy,1lx8ddGT5wCD6W2xmLeRKG,10vkYRKw6Jjr7try1ir50G,3cfnGXJ9bmiWvFqEO6ff8B,3IDc87lrpEHWFBASmgTgFV,0KOE1hat4SIer491XKk4Pa,6Ro2z4RtAUew9Kz2HZWZUi,1j2LuIf7mv15ZVug1Xy5qz,7IljDTNkQEyy77CcaRbiAj,1ckU1EhAO0Nr73QYw24SWJ,2yCAGizViD7HZXwNYxJToQ,5ZoDwIP1ntHwciLjydJ8X2,23IK8TF2MSiLnuEjaYPfVV,7JOyY9GA3P2Evx50oetDKb,1qfDfZAvrkSAFrAR2FTQDv,73GR50SgGV5hybgWDSFWtD,6lUXneXZ9jc3HSMHgd8oqh,5GvWrvLIqoHroq7YvO260M,02srSkeu2pzybuVr2B9TJm,5HrVgmO1govSOrPUehW1VV,3nsJGZ5RV2ZHkbKvD771gU,39Bd345OWEhRNyfayhp9gv,61sQYdFNS6sEBYCyr1q5gn,2ezqQeBiC72gwMJoO4w1hA,0ACACkoHUwg
DnJmpSvBNxngDOBeI5U0B,7fAe2PjWPfVdEur3xUCcvt,1WXEEP03cUcXYp96MxAO2M,2IkM8zrt6Y1F344CNfaDA0,4qawsTQMIjiRZvbJB0vp7i,0DEwNI2DgasX1eprqCivJk,2Dlo3MHqNxgRKOX6KAmWWO,3FPaQv0qldYuF0XD0ziwT8,77Fs4XIB6489MG4cpNwBms,1ehhGlTvjtHo2e4xJFB0SZ,6hAbyCJyTae5mEKWmAAFkm,3d6UefBBvhqHxJLZdm8scF,0PKcHf6NgPitUVFwzKnz3c,0JB6XDnV6U6M9U6j4VotoH,0epdaOT9HBO8Mm7ykRuFpT,1OOT5tLOCpvg5VFZVeMYC5,1KT3ndndHOGXePgC4o0Jq9,4X574HplOe89kLaj4a4Cnq,53ZRlP6Vv96bG0mc25DW2u,6mFrqPaHyaY4AcsYxHuD5G,22nqc8OGp6fhEQlTdSs476,0NnM0CgQaifZmhDquugyZV,7o9d4vFTq7SQ4vx60dpe5D,3jlKeObN7azQvrySwLdvP3,20oUeycXhRS3iNp0Hl32hh,7HKEVy7TpNKIAZ9o79KSOC,7D3rmjinop0EDd9ouwTaT1,7bmvCeN6JaeGN448OEGgLW,3tCLYifmzJhJHjUTTfPu0P,2f28m5YwEAh9aHOG14ajDD,2VUsmzlxjarwAVMCI2bm9x,31S04SZjQCMUTEIF9PWIEp,2zC0uKFfERvtOYNKendhEs,6HHlyBUx4YGVE95GF0orTe,5Jg9DV3m2umJpoHXV2e6j8,1FjyfUBL7Dj1GpSxL1XLCQ,1nrIaUgk4D5gI1yqQcsu3W,2PMW9aVSHvMwUC428yfDqx,1BDohKyV2EJ6iOmvx1K2FW,5LvUhG3juSj0TnCoHifKd7,19mXqYcLHY716cN53T1d1E,3hyp18EIQAjAFqVAMcpCQJ:
#  invalid request, reason: None

# %%
fifth_playlist = pd.concat([playlist5_info, features5_info], axis=1)
fifth_playlist.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vp/2wvfyb695rg5q5v9fgk55vpr0000gn/T/ipykernel_90094/3602814704.py in <module>
# ----> 1 fifth_playlist = pd.concat([playlist5_info, features5_info], axis=1)
#       2 fifth_playlist.reset_index()
#
# NameError: name 'features5_info' is not defined

# %%
sixth_playlist = sp.user_playlist_tracks("Spotify", "37i9dQZF1DXcgZcN2HVMoe")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
sixth_results = get_tracks("Spotify", "37i9dQZF1DXcgZcN2HVMoe")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = sixth_results
for r in sixth_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist6_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features6_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features6_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features6_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[199:]))
features6 = pd.concat([features6_info, features6_info2, features6_info3])
features6.reset_index(drop=True, inplace=True)

# %%
sixth_playlist = pd.concat([playlist6_info, features6], axis=1)
sixth_playlist.reset_index()
# Out:
#      index          song_name                 song_id           artist  \
# 0        0  Until I Found You  0T5iIrXA4p5GsubkhuBIKV  Stephen Sanchez
# 1        1                 TV  3GYlZ7tbxLOxe6ewMNVTkw    Billie Eilish
# 2        2          Coastline  4sDbdBjuYQVdNNB4PiHUPo     Hollow Coves
# 3        3             Beyond  1Omt5bfz1tZUCqd26HxbS0     Leon Bridges
# 4        4       Hold My Girl  42bbDWZ8WmXTH7PkYAlGLu      George Ezra
# ..     ...                ...                     ...              ...
# 195    195             Dakota  2LOEgB0Jk9suqAP5dDS4bp      Tom Speight
# 196    196          Fireworks  6qIUd9qdVd3xtVYT6CAQZn          Hazlett
# 197    197    Blinding Lights  66aMnwdhkEc1V0AAnyYchX      Teddy Swims
# 198    198          Microdose  1EdPgv2qJv1wu1zHsFfR1v     John Craigie
# 199    199       Mid Sentence  5z78SPUoa0zZcb1uWbwPMH      Xavier Dunn
#
#      danceability  energy  key  loudness  mode  speechiness  ...  liveness  \
# 0           0.539   0.508   10    -6.050     1       0.0288  ...    0.1740
# 1           0.412   0.236    4   -15.159     0       0.0379  ...    0.1470
# 2           0.670   0.496    2   -11.230     1       0.0277  ...    0.0584
# 3           0.581   0.687    6    -5.400     1       0.1050  ...    0.1090
# 4           0.614   0.527   10    -6.374     1       0.0302  ...    0.1100
# ..            ...     ...  ...       ...   ...          ...  ...       ...
# 195         0.621   0.296    3    -9.801     1       0.0291  ...    0.1030
# 196         0.693   0.388    9   -11.328     1       0.0338  ...    0.1070
# 197         0.512   0.543    0    -6.915     0       0.0310  ...    0.1120
# 198         0.676   0.479    5   -11.438     1       0.0280  ...    0.0631
# 199         0.462   0.108    2   -14.654     1       0.0638  ...    0.1600
#
#      valence    tempo            type                      id  \
# 0     0.2270  101.358  audio_features  0T5iIrXA4p5GsubkhuBIKV
# 1     0.1190  140.214  audio_features  3GYlZ7tbxLOxe6ewMNVTkw
# 2     0.4270  100.170  audio_features  4sDbdBjuYQVdNNB4PiHUPo
# 3     0.1870   76.014  audio_features  1Omt5bfz1tZUCqd26HxbS0
# 4     0.3540  121.941  audio_features  42bbDWZ8WmXTH7PkYAlGLu
# ..       ...      ...             ...                     ...
# 195   0.2570  121.918  audio_features  2LOEgB0Jk9suqAP5dDS4bp
# 196   0.0616  134.005  audio_features  6qIUd9qdVd3xtVYT6CAQZn
# 197   0.4420  159.900  audio_features  66aMnwdhkEc1V0AAnyYchX
# 198   0.3230  106.018  audio_features  1EdPgv2qJv1wu1zHsFfR1v
# 199   0.4190   77.972  audio_features  5z78SPUoa0zZcb1uWbwPMH
#
#                                       uri  \
# 0    spotify:track:0T5iIrXA4p5GsubkhuBIKV
# 1    spotify:track:3GYlZ7tbxLOxe6ewMNVTkw
# 2    spotify:track:4sDbdBjuYQVdNNB4PiHUPo
# 3    spotify:track:1Omt5bfz1tZUCqd26HxbS0
# 4    spotify:track:42bbDWZ8WmXTH7PkYAlGLu
# ..                                    ...
# 195  spotify:track:2LOEgB0Jk9suqAP5dDS4bp
# 196  spotify:track:6qIUd9qdVd3xtVYT6CAQZn
# 197  spotify:track:66aMnwdhkEc1V0AAnyYchX
# 198  spotify:track:1EdPgv2qJv1wu1zHsFfR1v
# 199  spotify:track:5z78SPUoa0zZcb1uWbwPMH
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0T5iIrXA4p5G...
# 1    https://api.spotify.com/v1/tracks/3GYlZ7tbxLOx...
# 2    https://api.spotify.com/v1/tracks/4sDbdBjuYQVd...
# 3    https://api.spotify.com/v1/tracks/1Omt5bfz1tZU...
# 4    https://api.spotify.com/v1/tracks/42bbDWZ8WmXT...
# ..                                                 ...
# 195  https://api.spotify.com/v1/tracks/2LOEgB0Jk9su...
# 196  https://api.spotify.com/v1/tracks/6qIUd9qdVd3x...
# 197  https://api.spotify.com/v1/tracks/66aMnwdhkEc1...
# 198  https://api.spotify.com/v1/tracks/1EdPgv2qJv1w...
# 199  https://api.spotify.com/v1/tracks/5z78SPUoa0zZ...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0T5i...      177720
# 1    https://api.spotify.com/v1/audio-analysis/3GYl...      281381
# 2    https://api.spotify.com/v1/audio-analysis/4sDb...      233973
# 3    https://api.spotify.com/v1/audio-analysis/1Omt...      240600
# 4    https://api.spotify.com/v1/audio-analysis/42bb...      211764
# ..                                                 ...         ...
# 195  https://api.spotify.com/v1/audio-analysis/2LOE...      294499
# 196  https://api.spotify.com/v1/audio-analysis/6qIU...      242015
# 197  https://api.spotify.com/v1/audio-analysis/66aM...      214875
# 198  https://api.spotify.com/v1/audio-analysis/1EdP...      335860
# 199  https://api.spotify.com/v1/audio-analysis/5z78...      184342
#
#     time_signature
# 0                3
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 195              4
# 196              4
# 197              4
# 198              4
# 199              4
#
# [200 rows x 22 columns]

# %%
seventh_playlist = sp.user_playlist_tracks("Arian", "5dxn0i8MPl6XFVVxNatd6U")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
seventh_results = get_tracks("Arian", "5dxn0i8MPl6XFVVxNatd6U")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = seventh_results
for r in seventh_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist7_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features7_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features7_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features7_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[199:299]))
features7_info4 = pd.DataFrame(sp.audio_features(tracks = song_id[299:399]))
features7_info5 = pd.DataFrame(sp.audio_features(tracks = song_id[399:499]))
features7_info6 = pd.DataFrame(sp.audio_features(tracks = song_id[499:]))
features7 = pd.concat([features7_info, features7_info2, features7_info3, features7_info4, features7_info5, features7_info6])
features7.reset_index(drop=True, inplace=True)

# %%
seventh_playlist = pd.concat([playlist7_info, features7], axis=1)
seventh_playlist.reset_index()
# Out:
#      index                song_name                 song_id            artist  \
# 0        0                  Respect  7s25THrKz86DM225dOYwnr   Aretha Franklin
# 1        1          Fight The Power  1yo16b3u0lptm6Cs7lx4AD      Public Enemy
# 2        2   A Change Is Gonna Come  0KOE1hat4SIer491XKk4Pa         Sam Cooke
# 3        3     Like a Rolling Stone  3AhXZa8sUQht0UEdBJgpGc         Bob Dylan
# 4        4  Smells Like Teen Spirit  5ghIJDpPoe3CfHMGu71E6T           Nirvana
# ..     ...                      ...                     ...               ...
# 495    495              Without You  6MrILERJLA3Jcq0E9poZsp     Harry Nilsson
# 496    496              Truth Hurts  3HWzoMvoF3TQfYg4UPszDq             Lizzo
# 497    497         Pancho and Lefty  42Wb5T7YmdrzVD81cUWWAg  Townes Van Zandt
# 498    498                Baby Love  5uES1C2NgkdrNHiCwf9jRr      The Supremes
# 499    499                 Stronger  4fzsfWzRhPawzqhX8Qt9F3        Kanye West
#
#      danceability  energy  key  loudness  mode  speechiness  ...  liveness  \
# 0           0.805   0.558    0    -5.226     1       0.0410  ...    0.0546
# 1           0.797   0.582    2   -12.970     1       0.2550  ...    0.5170
# 2           0.212   0.383   10   -10.071     1       0.0347  ...    0.2990
# 3           0.482   0.721    0    -6.839     1       0.0321  ...    0.1890
# 4           0.502   0.912    1    -4.556     1       0.0564  ...    0.1060
# ..            ...     ...  ...       ...   ...          ...  ...       ...
# 495         0.381   0.186    4   -15.477     1       0.0290  ...    0.0694
# 496         0.715   0.624    4    -3.046     0       0.1140  ...    0.1230
# 497         0.257   0.453    2    -8.063     1       0.0305  ...    0.5640
# 498         0.595   0.643    5    -9.275     1       0.0365  ...    0.5380
# 499         0.617   0.717   10    -7.858     0       0.1530  ...    0.4080
#
#      valence    tempo            type                      id  \
# 0      0.965  114.950  audio_features  7s25THrKz86DM225dOYwnr
# 1      0.415  105.974  audio_features  1yo16b3u0lptm6Cs7lx4AD
# 2      0.452  173.790  audio_features  0KOE1hat4SIer491XKk4Pa
# 3      0.557   95.263  audio_features  3AhXZa8sUQht0UEdBJgpGc
# 4      0.720  116.761  audio_features  5ghIJDpPoe3CfHMGu71E6T
# ..       ...      ...             ...                     ...
# 495    0.142   65.058  audio_features  6MrILERJLA3Jcq0E9poZsp
# 496    0.412  158.087  audio_features  3HWzoMvoF3TQfYg4UPszDq
# 497    0.397  148.848  audio_features  42Wb5T7YmdrzVD81cUWWAg
# 498    0.730  135.633  audio_features  5uES1C2NgkdrNHiCwf9jRr
# 499    0.490  103.992  audio_features  4fzsfWzRhPawzqhX8Qt9F3
#
#                                       uri  \
# 0    spotify:track:7s25THrKz86DM225dOYwnr
# 1    spotify:track:1yo16b3u0lptm6Cs7lx4AD
# 2    spotify:track:0KOE1hat4SIer491XKk4Pa
# 3    spotify:track:3AhXZa8sUQht0UEdBJgpGc
# 4    spotify:track:5ghIJDpPoe3CfHMGu71E6T
# ..                                    ...
# 495  spotify:track:6MrILERJLA3Jcq0E9poZsp
# 496  spotify:track:3HWzoMvoF3TQfYg4UPszDq
# 497  spotify:track:42Wb5T7YmdrzVD81cUWWAg
# 498  spotify:track:5uES1C2NgkdrNHiCwf9jRr
# 499  spotify:track:4fzsfWzRhPawzqhX8Qt9F3
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/7s25THrKz86D...
# 1    https://api.spotify.com/v1/tracks/1yo16b3u0lpt...
# 2    https://api.spotify.com/v1/tracks/0KOE1hat4SIe...
# 3    https://api.spotify.com/v1/tracks/3AhXZa8sUQht...
# 4    https://api.spotify.com/v1/tracks/5ghIJDpPoe3C...
# ..                                                 ...
# 495  https://api.spotify.com/v1/tracks/6MrILERJLA3J...
# 496  https://api.spotify.com/v1/tracks/3HWzoMvoF3TQ...
# 497  https://api.spotify.com/v1/tracks/42Wb5T7Ymdrz...
# 498  https://api.spotify.com/v1/tracks/5uES1C2Ngkdr...
# 499  https://api.spotify.com/v1/tracks/4fzsfWzRhPaw...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/7s25...      147600
# 1    https://api.spotify.com/v1/audio-analysis/1yo1...      282640
# 2    https://api.spotify.com/v1/audio-analysis/0KOE...      191160
# 3    https://api.spotify.com/v1/audio-analysis/3AhX...      369600
# 4    https://api.spotify.com/v1/audio-analysis/5ghI...      301920
# ..                                                 ...         ...
# 495  https://api.spotify.com/v1/audio-analysis/6MrI...      201000
# 496  https://api.spotify.com/v1/audio-analysis/3HWz...      173325
# 497  https://api.spotify.com/v1/audio-analysis/42Wb...      241080
# 498  https://api.spotify.com/v1/audio-analysis/5uES...      158040
# 499  https://api.spotify.com/v1/audio-analysis/4fzs...      311867
#
#     time_signature
# 0                4
# 1                4
# 2                3
# 3                4
# 4                4
# ..             ...
# 495              4
# 496              4
# 497              4
# 498              4
# 499              4
#
# [500 rows x 22 columns]

# %%
eighth_playlist = sp.user_playlist_tracks("Marcel", "6OAF6gkxAe4lqHdSLmGpdd")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
eighth_results = get_tracks("Marcel", "6OAF6gkxAe4lqHdSLmGpdd")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = eighth_results
for r in eighth_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist8_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features8_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features8_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features8_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[199:299]))
features8_info4 = pd.DataFrame(sp.audio_features(tracks = song_id[299:399]))
features8_info5 = pd.DataFrame(sp.audio_features(tracks = song_id[399:499]))
features8_info6 = pd.DataFrame(sp.audio_features(tracks = song_id[499:599]))
features8_info7 = pd.DataFrame(sp.audio_features(tracks = song_id[599:699]))
features8_info8 = pd.DataFrame(sp.audio_features(tracks = song_id[699:799]))
features8_info9 = pd.DataFrame(sp.audio_features(tracks = song_id[799:899]))
features8_info10 = pd.DataFrame(sp.audio_features(tracks = song_id[899:999]))
features8_info11 = pd.DataFrame(sp.audio_features(tracks = song_id[999:]))
features8 = pd.concat([features8_info, features8_info2, features8_info3, features8_info4, features8_info5, features8_info6, features8_info7, features8_info8, features8_info9, features8_info10, features8_info11])
features8.reset_index(drop=True, inplace=True)

# %%
eighth_playlist = pd.concat([playlist8_info, features8], axis=1)
eighth_playlist.reset_index()
# Out:
#       index                                          song_name  \
# 0         0                                 I'm Still Standing
# 1         1                                           Le Freak
# 2         2                                        I Feel Love
# 3         3                                          Blueprint
# 4         4                                 Life Is For Living
# ...     ...                                                ...
# 1077   1077  My Baby Just Cares for Me - 2013 Remastered Ve...
# 1078   1078                                 Do You Wanna Dance
# 1079   1079                         Working My Way Back to You
# 1080   1080                          I Can Hear Your Heartbeat
# 1081   1081                             Looking for the Summer
#
#                      song_id                       artist  danceability  \
# 0     5fwP61Nmo5xXYIjO9XEWqb                   Elton John         0.504
# 1     28NBmftocOzTPEb6OYA9fW                         CHIC         0.867
# 2     6efRrfjV1YW1rtecLUHoP1                 Donna Summer         0.690
# 3     1RuzwWdidBXXMVpwoBBIL1                    Rainbirds         0.475
# 4     6OAVhdZQs1KMNH1TfXbFJE        Barclay James Harvest         0.700
# ...                      ...                          ...           ...
# 1077  6VTbbVjKOC2qWagIDbkJrC                  Nina Simone         0.746
# 1078  21J0jPiMlIpXpKVFjyARP4  Cliff Richard & The Shadows         0.648
# 1079  7cLkQkC9Z7hnN767rfRl5G                 The Spinners         0.818
# 1080  7n0lp1r1yHYXN2jZvqzbAI                    Chris Rea         0.689
# 1081  2hTXUPiLY6GyUxESfOSKpL                    Chris Rea         0.565
#
#       energy  key  loudness  mode  speechiness  ...  liveness  valence  \
# 0      0.904    6    -6.863     1       0.1790  ...    0.1400    0.772
# 1      0.746    7    -7.445     1       0.0475  ...    0.1230    0.933
# 2      0.675    0   -16.247     1       0.0433  ...    0.0987    0.940
# 3      0.757    0   -12.237     0       0.0451  ...    0.1470    0.715
# 4      0.565    7   -14.761     1       0.0823  ...    0.0724    0.919
# ...      ...  ...       ...   ...          ...  ...       ...      ...
# 1077   0.243    4   -15.134     0       0.1230  ...    0.0905    0.425
# 1078   0.639    7   -15.287     1       0.0564  ...    0.1080    0.953
# 1079   0.768    9    -6.975     0       0.0482  ...    0.1070    0.922
# 1080   0.722    7    -8.575     1       0.0313  ...    0.0488    0.970
# 1081   0.670   11   -13.777     0       0.0320  ...    0.0518    0.253
#
#         tempo            type                      id  \
# 0     176.808  audio_features  5fwP61Nmo5xXYIjO9XEWqb
# 1     118.616  audio_features  28NBmftocOzTPEb6OYA9fW
# 2     128.100  audio_features  6efRrfjV1YW1rtecLUHoP1
# 3     194.193  audio_features  1RuzwWdidBXXMVpwoBBIL1
# 4     103.109  audio_features  6OAVhdZQs1KMNH1TfXbFJE
# ...       ...             ...                     ...
# 1077  118.578  audio_features  6VTbbVjKOC2qWagIDbkJrC
# 1078   84.164  audio_features  21J0jPiMlIpXpKVFjyARP4
# 1079  121.562  audio_features  7cLkQkC9Z7hnN767rfRl5G
# 1080  123.145  audio_features  7n0lp1r1yHYXN2jZvqzbAI
# 1081   95.027  audio_features  2hTXUPiLY6GyUxESfOSKpL
#
#                                        uri  \
# 0     spotify:track:5fwP61Nmo5xXYIjO9XEWqb
# 1     spotify:track:28NBmftocOzTPEb6OYA9fW
# 2     spotify:track:6efRrfjV1YW1rtecLUHoP1
# 3     spotify:track:1RuzwWdidBXXMVpwoBBIL1
# 4     spotify:track:6OAVhdZQs1KMNH1TfXbFJE
# ...                                    ...
# 1077  spotify:track:6VTbbVjKOC2qWagIDbkJrC
# 1078  spotify:track:21J0jPiMlIpXpKVFjyARP4
# 1079  spotify:track:7cLkQkC9Z7hnN767rfRl5G
# 1080  spotify:track:7n0lp1r1yHYXN2jZvqzbAI
# 1081  spotify:track:2hTXUPiLY6GyUxESfOSKpL
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5fwP61Nmo5xX...
# 1     https://api.spotify.com/v1/tracks/28NBmftocOzT...
# 2     https://api.spotify.com/v1/tracks/6efRrfjV1YW1...
# 3     https://api.spotify.com/v1/tracks/1RuzwWdidBXX...
# 4     https://api.spotify.com/v1/tracks/6OAVhdZQs1KM...
# ...                                                 ...
# 1077  https://api.spotify.com/v1/tracks/6VTbbVjKOC2q...
# 1078  https://api.spotify.com/v1/tracks/21J0jPiMlIpX...
# 1079  https://api.spotify.com/v1/tracks/7cLkQkC9Z7hn...
# 1080  https://api.spotify.com/v1/tracks/7n0lp1r1yHYX...
# 1081  https://api.spotify.com/v1/tracks/2hTXUPiLY6Gy...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5fwP...      183440
# 1     https://api.spotify.com/v1/audio-analysis/28NB...      327573
# 2     https://api.spotify.com/v1/audio-analysis/6efR...      493600
# 3     https://api.spotify.com/v1/audio-analysis/1Ruz...      331467
# 4     https://api.spotify.com/v1/audio-analysis/6OAV...      218933
# ...                                                 ...         ...
# 1077  https://api.spotify.com/v1/audio-analysis/6VTb...      215747
# 1078  https://api.spotify.com/v1/audio-analysis/21J0...      135600
# 1079  https://api.spotify.com/v1/audio-analysis/7cLk...      242667
# 1080  https://api.spotify.com/v1/audio-analysis/7n0l...      211146
# 1081  https://api.spotify.com/v1/audio-analysis/2hTX...      303600
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ...             ...
# 1077              4
# 1078              4
# 1079              4
# 1080              4
# 1081              4
#
# [1082 rows x 22 columns]

# %%
ninth_playlist = sp.user_playlist_tracks("Jimmy Alexander", "6aCHA5HeRfz5gJjllGZ7Of")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
ninth_results = get_tracks("Jimmy Alexander", "6aCHA5HeRfz5gJjllGZ7Of")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = ninth_results
for r in ninth_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist9_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})

# %%
features9_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features9_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features9_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[199:299]))
features9_info4 = pd.DataFrame(sp.audio_features(tracks = song_id[299:399]))
features9_info5 = pd.DataFrame(sp.audio_features(tracks = song_id[399:499]))
features9_info6 = pd.DataFrame(sp.audio_features(tracks = song_id[499:599]))
features9_info7 = pd.DataFrame(sp.audio_features(tracks = song_id[599:699]))
features9_info8 = pd.DataFrame(sp.audio_features(tracks = song_id[699:799]))
features9_info9 = pd.DataFrame(sp.audio_features(tracks = song_id[799:899]))
features9_info10 = pd.DataFrame(sp.audio_features(tracks = song_id[899:999]))
features9_info11 = pd.DataFrame(sp.audio_features(tracks = song_id[999:]))
features9 = pd.concat([features9_info, features9_info2, features9_info3, features9_info4, features9_info5, features9_info6, features9_info7, features9_info8, features9_info9, features9_info10, features9_info11])
features9.reset_index(drop=True, inplace=True)

# %%
ninth_playlist = pd.concat([playlist9_info, features9], axis=1)
ninth_playlist.reset_index()
# Out:
#       index                               song_name                 song_id  \
# 0         0                             'O Sole Mio  0oRa6dxPCzotYzujp21QFK
# 1         1  St. Louis Blues (with Louis Armstrong)  4ejUoPIMggFTVrAyvodqJQ
# 2         2                      Allons A Lafayette  3zZyFcJZ84mjQWLNrtMr2Z
# 3         3                         Lágrimas Negras  5UmrMwj8Ouw6yeg3TxQ9GA
# 4         4                     St. James Infirmary  7fAa9rz4UmwuB4AGh50Gmp
# ...     ...                                     ...                     ...
# 1028   1028                                  Tilted  4U6GYrZi0xvNkUmFitCDED
# 1029   1029                         Million Reasons  7dZ1Odmx9jWIweQSatnRqo
# 1030   1030                                    Lord  09CViXNGyH05AItXMtM6fC
# 1031   1031                           STREET LIVIN'  6NjcOqkCcsbO65KhM5Af2K
# 1032   1032                                 Dancing  6eMjHCnoLFjRJ3BZdtFXHo
#
#                                          artist  danceability  energy  key  \
# 0                                 Enrico Caruso         0.287   0.149    7
# 1                                  Bessie Smith         0.408   0.145   10
# 2                    Joe Falcon & Cleoma Breaux         0.533   0.405    7
# 3                                Trio Matamoros         0.613   0.305    0
# 4     Louis Armstrong & His Savoy Ballroom Five         0.693   0.182    5
# ...                                         ...           ...     ...  ...
# 1028                   Christine and the Queens         0.872   0.361    7
# 1029                                  Lady Gaga         0.666   0.423    0
# 1030                              Young Fathers         0.226   0.328   10
# 1031                            Black Eyed Peas         0.693   0.730    4
# 1032                              Kylie Minogue         0.497   0.706    6
#
#       loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0      -13.503     1       0.0379  ...    0.2060    0.269  129.377
# 1      -10.990     1       0.0501  ...    0.1380    0.294   68.800
# 2      -14.048     1       0.0377  ...    0.3930    0.868   93.960
# 3      -10.041     0       0.2190  ...    0.1110    0.789   96.967
# 4      -11.022     0       0.0514  ...    0.1530    0.588  116.508
# ...        ...   ...          ...  ...       ...      ...      ...
# 1028    -9.880     1       0.0609  ...    0.1080    0.489  100.001
# 1029    -8.012     1       0.0430  ...    0.1060    0.154  129.890
# 1030    -9.804     1       0.0330  ...    0.0851    0.119  175.558
# 1031    -4.270     0       0.2210  ...    0.3820    0.592   99.633
# 1032    -4.554     1       0.0371  ...    0.3250    0.528  110.038
#
#                 type                      id  \
# 0     audio_features  0oRa6dxPCzotYzujp21QFK
# 1     audio_features  4ejUoPIMggFTVrAyvodqJQ
# 2     audio_features  3zZyFcJZ84mjQWLNrtMr2Z
# 3     audio_features  5UmrMwj8Ouw6yeg3TxQ9GA
# 4     audio_features  7fAa9rz4UmwuB4AGh50Gmp
# ...              ...                     ...
# 1028  audio_features  4U6GYrZi0xvNkUmFitCDED
# 1029  audio_features  7dZ1Odmx9jWIweQSatnRqo
# 1030  audio_features  09CViXNGyH05AItXMtM6fC
# 1031  audio_features  6NjcOqkCcsbO65KhM5Af2K
# 1032  audio_features  6eMjHCnoLFjRJ3BZdtFXHo
#
#                                        uri  \
# 0     spotify:track:0oRa6dxPCzotYzujp21QFK
# 1     spotify:track:4ejUoPIMggFTVrAyvodqJQ
# 2     spotify:track:3zZyFcJZ84mjQWLNrtMr2Z
# 3     spotify:track:5UmrMwj8Ouw6yeg3TxQ9GA
# 4     spotify:track:7fAa9rz4UmwuB4AGh50Gmp
# ...                                    ...
# 1028  spotify:track:4U6GYrZi0xvNkUmFitCDED
# 1029  spotify:track:7dZ1Odmx9jWIweQSatnRqo
# 1030  spotify:track:09CViXNGyH05AItXMtM6fC
# 1031  spotify:track:6NjcOqkCcsbO65KhM5Af2K
# 1032  spotify:track:6eMjHCnoLFjRJ3BZdtFXHo
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0oRa6dxPCzot...
# 1     https://api.spotify.com/v1/tracks/4ejUoPIMggFT...
# 2     https://api.spotify.com/v1/tracks/3zZyFcJZ84mj...
# 3     https://api.spotify.com/v1/tracks/5UmrMwj8Ouw6...
# 4     https://api.spotify.com/v1/tracks/7fAa9rz4Umwu...
# ...                                                 ...
# 1028  https://api.spotify.com/v1/tracks/4U6GYrZi0xvN...
# 1029  https://api.spotify.com/v1/tracks/7dZ1Odmx9jWI...
# 1030  https://api.spotify.com/v1/tracks/09CViXNGyH05...
# 1031  https://api.spotify.com/v1/tracks/6NjcOqkCcsbO...
# 1032  https://api.spotify.com/v1/tracks/6eMjHCnoLFjR...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0oRa...      204293
# 1     https://api.spotify.com/v1/audio-analysis/4ejU...      190107
# 2     https://api.spotify.com/v1/audio-analysis/3zZy...      176493
# 3     https://api.spotify.com/v1/audio-analysis/5Umr...      174520
# 4     https://api.spotify.com/v1/audio-analysis/7fAa...      191867
# ...                                                 ...         ...
# 1028  https://api.spotify.com/v1/audio-analysis/4U6G...      233247
# 1029  https://api.spotify.com/v1/audio-analysis/7dZ1...      205280
# 1030  https://api.spotify.com/v1/audio-analysis/09CV...      217120
# 1031  https://api.spotify.com/v1/audio-analysis/6Njc...      185413
# 1032  https://api.spotify.com/v1/audio-analysis/6eMj...      178880
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ...             ...
# 1028              4
# 1029              4
# 1030              3
# 1031              4
# 1032              4
#
# [1033 rows x 22 columns]

# %%
tenth_playlist = sp.user_playlist_tracks("AROL", "20JT4SnBRiiXBeIXr5f2c0")

# %%
def get_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
tenth_results = get_tracks("AROL", "20JT4SnBRiiXBeIXr5f2c0")

# %%
song_name = []
song_uri = []
song_id = []
song_artists = []
playlist = tenth_results
for r in tenth_results:
    song_name.append(r['track']['name'])
    song_uri.append(r['track']['uri'])
    song_id.append(r['track']['id'])
    song_artists.append(r['track']['artists'][0]['name'])
playlist10_info = pd.DataFrame({'song_name':song_name, 'song_id':song_id, 'artist':song_artists})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vp/2wvfyb695rg5q5v9fgk55vpr0000gn/T/ipykernel_90094/1077410690.py in <module>
#       5 playlist = tenth_results
#       6 for r in tenth_results:
# ----> 7     song_name.append(r['track']['name'])
#       8     song_uri.append(r['track']['uri'])
#       9     song_id.append(r['track']['id'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
features10_info = pd.DataFrame(sp.audio_features(tracks = song_id[0:99]))
features10_info2 = pd.DataFrame(sp.audio_features(tracks = song_id[99:199]))
features10_info3 = pd.DataFrame(sp.audio_features(tracks = song_id[199:299]))
features10_info4 = pd.DataFrame(sp.audio_features(tracks = song_id[299:399]))
features10_info5 = pd.DataFrame(sp.audio_features(tracks = song_id[399:499]))
features10_info6 = pd.DataFrame(sp.audio_features(tracks = song_id[499:599]))
features10_info7 = pd.DataFrame(sp.audio_features(tracks = song_id[599:699]))
features10_info8 = pd.DataFrame(sp.audio_features(tracks = song_id[699:799]))
features10_info9 = pd.DataFrame(sp.audio_features(tracks = song_id[799:899]))
features10_info10 = pd.DataFrame(sp.audio_features(tracks = song_id[899:999]))
features10_info11 = pd.DataFrame(sp.audio_features(tracks = song_id[999:1099]))
features10_info12 = pd.DataFrame(sp.audio_features(tracks = song_id[1099:1199]))
features10_info13 = pd.DataFrame(sp.audio_features(tracks = song_id[1199:1299]))
features10_info14 = pd.DataFrame(sp.audio_features(tracks = song_id[1299:1399]))
features10_info15 = pd.DataFrame(sp.audio_features(tracks = song_id[1399:1499]))
features10_info16 = pd.DataFrame(sp.audio_features(tracks = song_id[1499:1599]))
features10_info17 = pd.DataFrame(sp.audio_features(tracks = song_id[1599:1699]))
features10_info18 = pd.DataFrame(sp.audio_features(tracks = song_id[1699:1799]))
features10_info19 = pd.DataFrame(sp.audio_features(tracks = song_id[1799:1899]))
features10_info20 = pd.DataFrame(sp.audio_features(tracks = song_id[1899:1999]))
features10_info21 = pd.DataFrame(sp.audio_features(tracks = song_id[1999:2099]))
features10_info22 = pd.DataFrame(sp.audio_features(tracks = song_id[2099:2199]))
features10_info23 = pd.DataFrame(sp.audio_features(tracks = song_id[2199:2299]))
features10_info24 = pd.DataFrame(sp.audio_features(tracks = song_id[2299:2399]))
features10_info25 = pd.DataFrame(sp.audio_features(tracks = song_id[2399:2499]))
features10_info26 = pd.DataFrame(sp.audio_features(tracks = song_id[2499:2599]))
features10_info27 = pd.DataFrame(sp.audio_features(tracks = song_id[2599:2699]))
features10_info28 = pd.DataFrame(sp.audio_features(tracks = song_id[2699:2799]))
features10_info29 = pd.DataFrame(sp.audio_features(tracks = song_id[2799:2899]))
features10_info30 = pd.DataFrame(sp.audio_features(tracks = song_id[2899:2999]))
features10_info31 = pd.DataFrame(sp.audio_features(tracks = song_id[2999:3099]))
features10_info32 = pd.DataFrame(sp.audio_features(tracks = song_id[3099:3199]))
features10_info33 = pd.DataFrame(sp.audio_features(tracks = song_id[3199:3299]))
features10_info34 = pd.DataFrame(sp.audio_features(tracks = song_id[3299:3399]))
features10_info35 = pd.DataFrame(sp.audio_features(tracks = song_id[3399:3499]))
features10_info36 = pd.DataFrame(sp.audio_features(tracks = song_id[3499:3599]))
features10_info37 = pd.DataFrame(sp.audio_features(tracks = song_id[3599:3699]))
features10_info38 = pd.DataFrame(sp.audio_features(tracks = song_id[3699:3799]))
features10_info39 = pd.DataFrame(sp.audio_features(tracks = song_id[3799:3899]))
features10_info40 = pd.DataFrame(sp.audio_features(tracks = song_id[3899:3999]))
features10_info41 = pd.DataFrame(sp.audio_features(tracks = song_id[3999:4099]))
features10_info42 = pd.DataFrame(sp.audio_features(tracks = song_id[4099:4199]))
features10_info43 = pd.DataFrame(sp.audio_features(tracks = song_id[4199:4299]))
features10_info44 = pd.DataFrame(sp.audio_features(tracks = song_id[4299:4399]))
features10_info45 = pd.DataFrame(sp.audio_features(tracks = song_id[4399:4499]))
features10_info46 = pd.DataFrame(sp.audio_features(tracks = song_id[4499:4599]))
features10_info47 = pd.DataFrame(sp.audio_features(tracks = song_id[4599:]))
features10 = pd.concat([features9_info, features10_info2, features10_info3, features10_info4, 
                        features10_info5, features10_info6, features10_info7, features10_info8, 
                        features10_info9, features10_info10, features10_info11, features10_info12, 
                        features10_info13, features10_info14, features10_info15, features10_info16, 
                        features10_info17, features10_info18, features10_info19, features10_info20, 
                        features10_info21, features10_info22, features10_info23, features10_info24, 
                        features10_info25, features10_info26, features10_info27, features10_info28, 
                        features10_info29, features10_info30, features10_info31, features10_info32, 
                        features10_info33, features10_info34, features10_info35, features10_info36, 
                        features10_info37, features10_info38, features10_info39, features10_info40, 
                        features10_info41, features10_info42, features10_info43, features10_info44, 
                        features10_info45, features10_info46, features10_info47])
features10.reset_index(drop=True, inplace=True)

# %%
tenth_playlist = pd.concat([playlist10_info, features10], axis=1)
tenth_playlist.reset_index()

# %%
huge_playlist = pd.concat([first_playlist, second_playlist, third_playlist, fourth_playlist, 
                           fifth_playlist, sixth_playlist, seventh_playlist, eighth_playlist, 
                           ninth_playlist, tenth_playlist])
huge_playlist.reset_index(drop=True, inplace=True)

# %%
huge_playlist.duplicated(subset='song_name', keep='first').sum()
huge_playlist = huge_playlist.drop_duplicates()
huge_playlist.reset_index(drop=True, inplace=True)
huge_playlist = huge_playlist.dropna()
huge_playlist.reset_index(drop=True, inplace=True)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import plotly 
import plotly.graph_objs as go
from sklearn.cluster import KMeans 
from sklearn import datasets 
from sklearn.preprocessing import StandardScaler

# %%
# copying the playlist just in case
hugeplaylist = huge_playlist.copy()

# %%
# dropping extra columns, leaving only the song to use later as index
hugeplaylist.drop(['artist', 'song_id', 'id', 'uri', 'track_href', 'mode', 'analysis_url', 
                   'duration_ms', 'time_signature', 'type'], axis = 1, inplace = True)

# %%
# Song as index!
hugeplaylist.index = hugeplaylist.iloc[:,0]
# pick first column and turn it to index [:,_] - location

# %%
#keep rest of columns
hugeplaylist = hugeplaylist.iloc[:,1:]

# %%
# remove the header name
hugeplaylist.rename_axis(None,inplace=True)

# %%
hugeplaylist_scaled = StandardScaler().fit_transform(hugeplaylist)

# %%
hugeplaylist_scaled_df = pd.DataFrame(hugeplaylist_scaled,columns = ['danceability', 'energy', 
                                                                     'key', 'loudness', 
                                                                     'speechiness', 'acousticness', 
                                                                     'instrumentalness', 'liveness', 
                                                                     'valence', 'tempo'])

# %%
kmeans = KMeans(n_clusters = 52)

# %%
cluster = kmeans.fit(hugeplaylist_scaled_df)

# %%
#bring cluster into data frame
hugeplaylist_c = hugeplaylist.copy()
hugeplaylist_c['cluster'] = cluster.labels_

# %%
### Adding the cluster column to the original dataframe and reoganizing the data


# In[72]:


huge_playlist['cluster'] = hugeplaylist_c['cluster'].values

# %%
# creating the cluster thing
from IPython.core.display import display
from IPython.display import IFrame

# %%
def song_cluster(song):
    song = sp.search(q = song, limit = 1)
    song_id = song['tracks']
    song_id = song_id['items'][0]['id']
    song_features = sp.audio_features(song_id)
    song_data = pd.DataFrame(song_features, index= [0])
   # droping the numeric columns i didn't use
    song_data.drop(['mode', 'duration_ms', 'time_signature'], axis = 1, inplace = True)  
    song_num = song_data._get_numeric_data()
    song_scaled = StandardScaler().fit_transform(song_num)
    cluster = kmeans.predict(song_scaled)
    song_cluster = huge_playlist.loc[huge_playlist['cluster'] == int(cluster)]
    song_cluster.reset_index(drop=True, inplace=True) 
    song_name_id = random.choice(song_cluster["id"])
    songname = sp.track(song_name_id)['name']
    artist = sp.track(song_name_id)['artists'][0]['name']
    def recommend(song_name_id):
        display(IFrame(src=f"https://open.spotify.com/embed/track/{song_name_id}",
                        width="320",
                        height="80",
                        frameborder="0",
                        allowtransparency="true",
                        allow="encrypted-media",))
    return print("\033[1m" + 'That song is not hot right now. But listen to ' + songname + ' by ' + artist + ". I think you'll like it!."), recommend(song_name_id)

# %%
##### practice other ways

# %%
# new suggester attempt

def second_suggester():
    song = str(input( "\033[1m" + """
    Welcome to the awesome song recommender!
    What song do you have in mind?: 
    """).lower().replace(" ", ''))
    # check hot 100
    check = billboard_top100[billboard_top100['song'].str.lower().str.replace(" ","").str.contains(song)]
    # get index
    index = check.index.tolist()
    if len(check) == 0:
        song_cluster(song)
        song2 = str(input("\033[1m" + "Want to try again? [y/n]: ")).lower().replace(" ", '')
        if song2 == 'y':
            print("\033[1m" + 'Awesome! Here, have another go:')
            second_suggester()
        elif song2 != 'n':
            print("\033[1m" + "Oh, come on, that's not an answer")
        elif song2 == 'n':
            print("\033[1m" + 'Oh well, your bad, this is an awesome recommender')
            return
    else:
        answer1 = input("\033[1m" + "Are you thinking about '" + billboard_top100.song[index].values[0] + "' by '" + billboard_top100.artist[index].values[0] + "'? [y/n]: ")
        #make a song suggestion
        if answer1.lower() == 'y':
            suggestion = billboard_top100.sample().index.tolist()
            print("\033[1m" + "That's a hot song! Listen to '" + billboard_top100['song'][suggestion].item() + "' by '" + billboard_top100['artist'][suggestion].item() + "' I think you'll like it.")
            song2 = str(input("\033[1m" + "Want to try again? [y/n]: ")).lower().replace(" ", '')
            if song2 == 'y':
                print("\033[1m" + 'Awesome! Here, have another go:')
                second_suggester()
            elif song2 != 'n':
                print("\033[1m" + "Oh, come on, that's not an answer")
            elif song2 == 'n':
                print("\033[1m" + 'Oh well, your bad, this is an awesome recommender')
                return
        elif answer1.lower() != 'n':
            print("\033[1m" + "Oh, come on, that's not an answer")
            song2 = str(input("\033[1m" + "Want to try again? [y/n]: ")).lower().replace(" ", '')
            second_suggester()
        elif answer1.lower() == 'n':
            song_cluster(song)
            song2 = str(input("\033[1m" + "Want to try again? [y/n]: ")).lower().replace(" ", '')
            if song2 == 'y':
                print("\033[1m" + 'Awesome! Here, have another go:')
                second_suggester()
            elif song2 != 'n':
                print("\033[1m" + "Oh, come on, that's not an answer")
            elif song2 == 'n':
                print("\033[1m" + 'Oh well, your bad, this is an awesome recommender')
                return
        elif song2 != 'n':
            print("\033[1m" + "Oh, come on, that's not an answer")
        elif song2 == 'n':
            print("\033[1m" + 'Oh well, your bad, this is an awesome recommender')
            return
second_suggester()
